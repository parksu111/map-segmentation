# %% [markdown]
# # Data Prep
# This notebook summarizes the steps that went into processing the raw data into the train and test data that was used for the competition.

# %%
import os 
import numpy as np
import json
import tifffile as tiff
import random
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

# %% [markdown]
# ## Examining the Raw Data

# %% [markdown]
# ### Different Data Files
#
# We have 3 different folders coontaining different data:
# * *raw_tiffs*
# * *label_json*
# * *meta*

# %%
rawtiffs_path = '/workspace/Competition/map_segmentation/data/RAW/train/raw_tiffs'
labeljsons_path = '/workspace/Competition/map_segmentation/data/RAW/train/label_json'
metafiles_path = '/workspace/Competition/map_segmentation/data/RAW/train/meta'

raw_tiffs = os.listdir(rawtiffs_path)
label_jsons = os.listdir(labeljsons_path)
meta_files = os.listdir(metafiles_path)

# %%
len(raw_tiffs), len(label_jsons), len(meta_files)
# Out:
# (13520, 13520, 13520)

# %% [markdown]
# We have 13,520 files of each type. Let's examine the names of the files in each folder.

# %%
print(raw_tiffs[0:5])
# Out:
# ['LC_AP_37607046_001.tif', 'LC_AP_37607046_002.tif', 'LC_AP_37607046_003.tif', 'LC_AP_37607046_004.tif', 'LC_AP_37607046_005.tif']

# %%
print(label_jsons[0:5])
# Out:
# ['LC_AP_37607046_001_FGT.json', 'LC_AP_37607046_002_FGT.json', 'LC_AP_37607046_003_FGT.json', 'LC_AP_37607046_004_FGT.json', 'LC_AP_37607046_005_FGT.json']

# %%
print(meta_files[0:5])
# Out:
# ['LC_AP_37607046_004_META.json', 'LC_AP_37607046_005_META.json', 'LC_AP_37607046_006_META.json', 'LC_AP_37607046_007_META.json', 'LC_AP_37607046_008_META.json']

# %% [markdown]
# From the names of the files, it seems like there are label files ('_FGT.json') and meta files ('_META.json') corresponding to each image file ('.tif'). We check to see if this is the case:

# %%
rawtiff_names = [x.split('.')[0] for x in raw_tiffs]
labeljson_names = [x.split('_FGT')[0] for x in label_jsons]
metafile_names = [x.split('_META')[0] for x in meta_files]

# %%
rawtiff_names.sort()
labeljson_names.sort()
metafile_names.sort()

# %%
rawtiff_names == labeljson_names
# Out:
# True

# %%
rawtiff_names == metafile_names
# Out:
# True

# %% [markdown]
# We confirm that there are label and meta files corresponding to each image file.

# %% [markdown]
# ### Images

# %% [markdown]
# #### Example of 1 image

# %%
im1_path = os.path.join(rawtiffs_path, raw_tiffs[0])
im1 = tiff.imread(im1_path)

plt.figure()
plt.imshow(im1)

# %%
im1.shape
# Out:
# (512, 512, 3)

# %% [markdown]
# We can see that the image is an aerial image of a crossroad and has size 512*512 px with 3 color channels.

# %% [markdown]
# #### Multiple images

# %%
img_samples = random.sample(raw_tiffs, 9)

plt.figure(figsize=(20,20))
for i in range(9):
    plt.subplot(3,3,i+1)
    impath = os.path.join(rawtiffs_path, img_samples[i])
    im = tiff.imread(impath)
    plt.imshow(im)

# %% [markdown]
# #### Image Sizes

# %%
img_sizes = []

for imname in raw_tiffs:
    impath = os.path.join(rawtiffs_path, imname)
    im = tiff.imread(impath)
    img_sizes.append(im.shape)

# %%
set(img_sizes)
# Out:
# {(512, 512, 3)}

# %% [markdown]
# It seems that all image files have the same size: (512,512,3)

# %% [markdown]
# ### Label files

# %% [markdown]
# We now move on and see what kind of information the label json files contain.

# %%
label1path = os.path.join(labeljsons_path, label_jsons[0])
label1 = json.load(open(label1path))

label1
# Out:
# {'type': 'FeatureCollection',
#  'name': 'LC_AP_37607046_001_FGT',
#  'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::5186'}},
#  'features': [{'type': 'Feature',
#    'properties': {'ANN_CD': 10, 'ANN_NM': '건물'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[167095.6468231578, 560792.150136266],
#       [167094.22999999954, 560792.150136266],
#       [167094.22999999954, 560795.3082871719],
#       [167095.02321734745, 560795.50801371],
#       [167095.6468231578, 560792.150136266]]]}},
#   {'type': 'Feature',
#    'properties': {'ANN_CD': 10, 'ANN_NM': '건물'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[167175.20775271166, 560792.150136266],
#       [167144.3805187422, 560792.150136266],
#       [167144.3805187422, 560794.1042602079],
#       [167149.44776496303, 560795.4685188083],
#       [167146.14136993943, 560808.3792041454],
#       [167149.21105429117, 560809.1521290217],
#       [167153.8840144171, 560810.1369387897],
#       [167174.05255905495, 560796.6912423607],
#       [167175.20775271166, 560792.150136266]]]}},
#   {'type': 'Feature',
#    'properties': {'ANN_CD': 10, 'ANN_NM': '건물'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[167322.8489230154, 560836.7208120805],
#       [167329.3022064185, 560828.9605345783],
#       [167298.3427835132, 560798.4095473225],
#       [167289.84732181768, 560799.6348542981],
#       [167277.43096556852, 560813.4547986492],
#       [167271.75339560368, 560818.6519574972],
#       [167272.0508035167, 560821.4628401108],
#       [167278.57449764758, 560827.4901662095],
#       [167285.35452957882, 560826.1014849667],
#       [167291.56275157974, 560819.4031401725],
#       [167291.8078129775, 560816.7074648172],
#       [167294.5851754565, 560814.0934766122],
#       [167296.46397948152, 560815.8089063744],
#       [167294.91192398462, 560817.5243361408],
#       [167301.2018331159, 560823.4058096203],
#       [167302.2637658284, 560822.425564036],
#       [167302.75388862166, 560823.0790611011],
#       [167298.83290630204, 560827.0000434185],
#       [167304.79606691631, 560832.9632040261],
#       [167308.71704923152, 560829.1239088346],
#       [167310.10573047213, 560830.3492158123],
#       [167309.1254848922, 560831.6562099203],
#       [167316.80407527077, 560838.2728675863],
#       [167322.8489230154, 560836.7208120805]]]}},
#   {'type': 'Feature',
#    'properties': {'ANN_CD': 10, 'ANN_NM': '건물'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[167147.8906156393, 560912.9727155493],
#       [167155.4518977344, 560906.7862120101],
#       [167141.15420067863, 560889.6014799795],
#       [167149.5403499126, 560879.1531629006],
#       [167143.07889066264, 560873.6540486393],
#       [167134.05695088927, 560871.3082479902],
#       [167133.10199448065, 560872.4221206134],
#       [167132.1562470495, 560871.6141280464],
#       [167129.10000803004, 560875.3060174391],
#       [167128.96613178935, 560875.1171041923],
#       [167125.07212533953, 560879.8731065515],
#       [167125.67502391397, 560880.3230123289],
#       [167121.83601482926, 560884.9551302389],
#       [167116.6459748314, 560887.8450982528],
#       [167116.35098333095, 560887.2200382691],
#       [167111.02207801936, 560890.1880939584],
#       [167111.16711855764, 560890.4528607074],
#       [167106.9911413878, 560892.7792325799],
#       [167107.66205699072, 560893.9060407782],
#       [167106.35507616375, 560894.6069910957],
#       [167110.10608116153, 560901.5020902543],
#       [167117.37053153935, 560904.4490884523],
#       [167121.49486722695, 560902.2494427552],
#       [167122.45721221785, 560903.899177033],
#       [167129.88396855313, 560900.0550365637],
#       [167130.61707684185, 560899.377035644],
#       [167132.18906786534, 560901.2031269942],
#       [167130.8500214682, 560902.252029814],
#       [167135.54008106675, 560908.0700849127],
#       [167136.87514719143, 560906.9830137955],
#       [167139.667088201, 560910.4451189712],
#       [167147.8906156393, 560912.9727155493]]]}},
#   {'type': 'Feature',
#    'properties': {'ANN_CD': 10, 'ANN_NM': '건물'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[167257.5760913255, 560945.6891326135],
#       [167258.49023651986, 560945.1001285907],
#       [167258.8738596837, 560945.4591001828],
#       [167264.05198388055, 560941.598990874],
#       [167264.7811187794, 560942.5980306603],
#       [167268.29999997563, 560939.8520081994],
#       [167267.87812527452, 560939.1590478806],
#       [167269.35596500337, 560937.9021436654],
#       [167268.66724444617, 560936.9560715902],
#       [167269.6060058754, 560935.9970003574],
#       [167262.83914319478, 560927.7550840958],
#       [167262.10399252176, 560928.4099989003],
#       [167252.04824081488, 560916.9412459965],
#       [167252.15199401972, 560916.1091373109],
#       [167256.9509757456, 560914.6271180671],
#       [167254.68312194844, 560908.2559734501],
#       [167248.91824949626, 560910.3850751801],
#       [167248.6602416809, 560909.7280008227],
#       [167237.4061213927, 560913.7559913207],
#       [167236.64699565776, 560911.251958025],
#       [167230.62204339448, 560913.2440587617],
#       [167224.57126933403, 560915.5848964335],
#       [167222.6234922111, 560919.7096009281],
#       [167227.66479770272, 560931.396263659],
#       [167214.946958846, 560941.7080248976],
#       [167222.6234922111, 560949.4991333914],
#       [167230.33012391775, 560945.0739915817],
#       [167233.26401963894, 560942.5081494094],
#       [167233.55495737024, 560942.6859964053],
#       [167237.6860067826, 560939.1609599106],
#       [167236.10803192388, 560936.9561020677],
#       [167241.54596520928, 560932.297961377],
#       [167243.7053151835, 560935.5209681579],
#       [167246.22596792597, 560933.8023412793],
#       [167247.37171917842, 560935.0626676605],
#       [167242.33041368236, 560938.9582219041],
#       [167243.81989030787, 560940.5622736474],
#       [167241.87211318495, 560942.3954756503],
#       [167244.85106642707, 560945.9473045209],
#       [167246.22596792597, 560944.916128395],
#       [167250.92354804897, 560950.301159262],
#       [167257.5760913255, 560945.6891326135]]]}},
#   {'type': 'Feature',
#    'properties': {'ANN_CD': 10, 'ANN_NM': '건물'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[167303.08405468304, 560957.2039552632],
#       [167306.06101160037, 560954.2950871632],
#       [167306.45287062673, 560954.6699747348],
#       [167310.13498484032, 560950.9340709016],
#       [167308.45498173495, 560949.0179722926],
#       [167311.89300661522, 560945.5640677403],
#       [167311.4541040348, 560944.9911256599],
#       [167313.41506898188, 560943.3300525164],
#       [167315.30307985898, 560941.6179725076],
#       [167316.68074947194, 560941.0159820998],
#       [167319.13762379717, 560944.6616665905],
#       [167320.86220445542, 560943.6472073828],
#       [167321.87666365417, 560944.6616665905],
#       [167317.81882682818, 560948.4151656551],
#       [167319.74629931996, 560949.9368544642],
#       [167318.32605643198, 560951.7628810349],
#       [167321.6737718162, 560954.7048127365],
#       [167322.99256878518, 560953.6903535288],
#       [167327.55763520833, 560958.661203639],
#       [167330.47312347498, 560955.7490913301],
#       [167331.45824807286, 560954.8750972905],
#       [167331.97995581533, 560955.4680212989],
#       [167336.49101220875, 560951.2539650323],
#       [167337.24800457526, 560952.1381454841],
#       [167340.60909014937, 560948.8178782534],
#       [167340.02024448663, 560948.2430364601],
#       [167341.44411208347, 560946.8051138818],
#       [167340.7491312696, 560946.1359730588],
#       [167341.71009084652, 560945.1720854511],
#       [167335.46202234458, 560938.4978563247],
#       [167334.48300476928, 560939.4151311666],
#       [167330.52697838063, 560935.366013729],
#       [167330.94207278514, 560934.9630827528],
#       [167327.3140790117, 560931.4959862899],
#       [167327.0509947526, 560931.9380082816],
#       [167322.57099769614, 560926.8760058968],
#       [167327.33608573672, 560924.7371393994],
#       [167324.44798793978, 560918.4080040146],
#       [167308.09408295064, 560925.4800994821],
#       [167306.99211027566, 560922.8152484024],
#       [167301.02000222076, 560925.593976296],
#       [167296.71807533968, 560927.3144141666],
#       [167296.00795390236, 560930.662129542],
#       [167298.74699375936, 560936.2416551859],
#       [167300.37012848974, 560935.7344255822],
#       [167303.61639794608, 560941.516843051],
#       [167291.54433339156, 560953.183123925],
#       [167299.1527774353, 560960.5886761287],
#       [167303.08405468304, 560957.2039552632]]]}},
#   {'type': 'Feature',
#    'properties': {'ANN_CD': 10, 'ANN_NM': '건물'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[167094.22999999954, 560956.6269933472],
#       [167094.22999999954, 560974.344726133],
#       [167101.58076709943, 560977.4742606434],
#       [167104.94401235756, 560975.8915569914],
#       [167105.438607251, 560977.3753416651],
#       [167113.28496253848, 560973.4710114154],
#       [167117.97512162945, 560979.2890673159],
#       [167119.2089874192, 560978.2019899201],
#       [167122.05012786016, 560981.664090976],
#       [167125.61807881534, 560982.5191285361],
#       [167128.18997224973, 560981.0353438625],
#       [167131.65213649056, 560985.3877789052],
#       [167138.97214088298, 560980.540748969],
#       [167124.6288890351, 560964.515874491],
#       [167124.03537515897, 560961.6472241218],
#       [167126.1126737088, 560962.1418190153],
#       [167131.84997444483, 560954.4261387099],
#       [167132.54240729476, 560951.2607314016],
#       [167124.39602387964, 560945.1307795263],
#       [167127.61010391888, 560941.1291482951],
#       [167115.78402664047, 560931.4960474982],
#       [167102.78113830625, 560947.4650850107],
#       [167104.65630425475, 560948.9858613648],
#       [167102.56995688187, 560951.4585693647],
#       [167094.22999999954, 560956.6269933472]]]}},
#   {'type': 'Feature',
#    'properties': {'ANN_CD': 10, 'ANN_NM': '건물'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[167235.44832668253, 561022.3768373806],
#       [167239.61278231879, 561018.5668034998],
#       [167240.67604758314, 561019.718674212],
#       [167247.45106380593, 561014.375072175],
#       [167251.12695805245, 561011.11497087],
#       [167250.6300716194, 561010.4600907428],
#       [167252.1220455698, 561009.1789533957],
#       [167251.4550368271, 561008.3822499528],
#       [167252.3109792602, 561007.5150700741],
#       [167246.52912252743, 561000.6071426548],
#       [167245.7649920909, 561001.3280599248],
#       [167242.0520826846, 560997.2390904585],
#       [167242.28295721186, 560997.0340480445],
#       [167238.82797794006, 560992.803136308],
#       [167238.44804530405, 560992.952864788],
#       [167235.0362410257, 560988.9580333263],
#       [167234.6110418231, 560987.9350046684],
#       [167239.56011861726, 560986.0289688446],
#       [167237.0860169526, 560979.6189777546],
#       [167231.6539914273, 560982.0771029466],
#       [167231.37610642423, 560981.2830740884],
#       [167220.0460842025, 560985.2279632568],
#       [167219.2311458744, 560982.8539786482],
#       [167213.33808564203, 560984.8221396599],
#       [167205.1452665255, 560988.6181651028],
#       [167204.17060669116, 560990.8333010792],
#       [167206.82876986422, 560998.0103416418],
#       [167207.892035133, 560997.6559198863],
#       [167210.28438198945, 561004.5671441323],
#       [167198.4998585917, 561013.9593206714],
#       [167205.5882937199, 561022.3768373806],
#       [167212.87296543794, 561016.5209695457],
#       [167215.95596410587, 561013.9490865096],
#       [167216.34400334957, 561014.3870425394],
#       [167220.34899553633, 561010.861067898],
#       [167218.6342404408, 561008.959122073],
#       [167224.1479811599, 561004.2108538988],
#       [167226.76499365893, 561007.9341508164],
#       [167228.18268068103, 561007.4025181831],
#       [167229.24594594535, 561008.7315997664],
#       [167224.99288487688, 561012.3644227649],
#       [167226.2333610212, 561013.9593206714],
#       [167224.72706855802, 561014.9339805035],
#       [167227.82825892328, 561018.744014382],
#       [167229.1573405087, 561017.7693545566],
#       [167232.52434719505, 561022.288231944],
#       [167235.44832668253, 561022.3768373806]]]}},
#   {'type': 'Feature',
#    'properties': {'ANN_CD': 10, 'ANN_NM': '건물'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[167355.3500000034, 561051.5041432474],
#       [167355.3500000034, 561020.6249100823],
#       [167354.76795464545, 561019.869103472],
#       [167355.3500000034, 561019.6463796619],
#       [167355.3500000034, 561012.3065894635],
#       [167340.93708294808, 561017.2949531376],
#       [167339.84911125764, 561014.5149691848],
#       [167333.76398862022, 561016.644131006],
#       [167330.68626264913, 561018.2002516985],
#       [167328.23079418365, 561023.1111886295],
#       [167330.3793290854, 561029.1475486158],
#       [167331.60706332483, 561028.6359926836],
#       [167333.90806349248, 561035.0740698952],
#       [167330.11112963877, 561038.3522328055],
#       [167322.6036789454, 561044.903471282],
#       [167329.45852841862, 561052.1675654965],
#       [167336.7549615332, 561046.1600408434],
#       [167340.6351471989, 561043.0090667136],
#       [167339.0710262581, 561040.8601027783],
#       [167343.34707305866, 561037.7990700483],
#       [167345.7260070126, 561036.6162652076],
#       [167344.9075175189, 561034.7746638496],
#       [167345.7260070126, 561034.3654191105],
#       [167349.920765643, 561039.5832896008],
#       [167352.27392292206, 561039.0717336687],
#       [167352.47854529938, 561040.0948455308],
#       [167348.79534259223, 561042.7549363713],
#       [167350.33001038874, 561044.3919153477],
#       [167348.48840903738, 561045.8242719576],
#       [167351.6600558057, 561049.814408213],
#       [167353.29703478861, 561048.7912963531],
#       [167355.3500000034, 561051.5041432474]]]}},
#   {'type': 'Feature',
#    'properties': {'ANN_CD': 30, 'ANN_NM': '도로'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[167263.41823240294, 560874.3272134445],
#       [167268.53786615707, 560849.0424916383],
#       [167252.12850295237, 560840.1413472962],
#       [167246.87071415008, 560836.0785104969],
#       [167243.76383894213, 560832.7326448906],
#       [167238.98403094328, 560824.6069712832],
#       [167236.35513654322, 560818.8712016819],
#       [167235.3991749408, 560813.8524032757],
#       [167232.171604658, 560792.31215418],
#       [167231.51453784498, 560792.150136266],
#       [167199.97451578872, 560792.150136266],
#       [167197.39395552597, 560796.5944344884],
#       [167192.16612500112, 560802.8678311276],
#       [167188.92487008058, 560806.109086046],
#       [167180.9785676768, 560811.5460297927],
#       [167175.0188408795, 560814.264501674],
#       [167169.79101035465, 560816.3556338736],
#       [167164.87684966277, 560817.4011999835],
#       [167159.75357574006, 560817.9239830318],
#       [167155.00338564828, 560818.0465508976],
#       [167151.3814842838, 560817.3351059853],
#       [167145.33964067846, 560845.7177201264],
#       [167149.42834647148, 560847.5534655827],
#       [167155.95522161067, 560852.0406922395],
#       [167162.07416705298, 560857.343778297],
#       [167166.96932340015, 560863.8706534251],
#       [167172.95229228275, 560874.204872396],
#       [167175.3998704597, 560881.1396772255],
#       [167176.75963610783, 560890.3860836765],
#       [167176.48768297955, 560895.825146287],
#       [167175.10128924533, 560901.5093605908],
#       [167203.79187169985, 560906.0340402627],
#       [167207.0824101844, 560898.1367479042],
#       [167207.30536615534, 560897.7709636857],
#       [167215.32398132954, 560887.2224561252],
#       [167222.25470292947, 560881.72567692],
#       [167226.31753973538, 560878.8577921238],
#       [167231.81431893609, 560876.2288977216],
#       [167234.68220373895, 560875.2729361169],
#       [167240.89595414372, 560873.361012921],
#       [167252.74010115582, 560872.8887947166],
#       [167256.4463261224, 560872.8885661135],
#       [167263.41823240294, 560874.3272134445]],
#      [[167220.9560545392, 560861.2992277081],
#       [167252.5820532714, 560868.6215018841],
#       [167240.17898293966, 560869.0591857143],
#       [167233.96523253713, 560870.971108917],
#       [167225.36157813072, 560874.3169745189],
#       [167219.8647989278, 560876.7068785205],
#       [167211.73912532264, 560882.2036577213],
#       [167205.38350820102, 560889.0889096056],
#       [167210.7578626337, 560868.7517525653],
#       [167212.06532313555, 560863.7834026605],
#       [167212.457561285, 560862.6066882123],
#       [167213.11129153924, 560861.5607198152],
#       [167214.2880059898, 560860.9069895587],
#       [167215.59546648496, 560860.5147514071],
#       [167220.9560545392, 560861.2992277081]],
#      [[167181.4619720925, 560851.8142010425],
#       [167189.57700251942, 560853.9774489023],
#       [167187.37853331747, 560863.6168907948],
#       [167181.62648472408, 560888.8374115597],
#       [167180.83893306568, 560888.6183883159],
#       [167179.3431908467, 560880.4597943936],
#       [167176.35170641096, 560871.3493645155],
#       [167174.17608136233, 560866.4542081617],
#       [167171.0486203602, 560861.8310049406],
#       [167169.6888547076, 560860.063309591],
#       [167165.47358118117, 560854.4882704099],
#       [167159.35463573664, 560849.1851843613],
#       [167151.19604181653, 560843.7461217464],
#       [167181.4619720925, 560851.8142010425]],
#      [[167232.2922997351, 560821.0221152807],
#       [167235.39917493856, 560827.7138464844],
#       [167237.311098139, 560831.0597120863],
#       [167249.5243168551, 560844.776096181],
#       [167225.27067419636, 560839.333891295],
#       [167219.12560984326, 560838.1571768422],
#       [167218.21038749086, 560837.6341926459],
#       [167217.5566572433, 560836.4574781931],
#       [167217.42591118976, 560835.6730018898],
#       [167219.2563558879, 560829.004953336],
#       [167225.97433590805, 560802.4755121925],
#       [167232.2922997351, 560821.0221152807]],
#      [[167196.7971003383, 560823.754737756],
#       [167194.6760984755, 560830.9661440876],
#       [167186.49145251626, 560829.2782599016],
#       [167162.25467509497, 560824.2800139759],
#       [167162.77406225278, 560823.1213810855],
#       [167166.95793585424, 560822.075412684],
#       [167171.01106340438, 560821.0294442825],
#       [167176.11015936045, 560819.4604916803],
#       [167180.29403296413, 560817.7607930313],
#       [167186.3083512704, 560814.6228878313],
#       [167189.8384946198, 560811.8772207807],
#       [167193.49938402273, 560809.131553728],
#       [167197.6832576264, 560804.2939498723],
#       [167204.48205223153, 560797.6259013207],
#       [167196.7971003383, 560823.754737756]]]}},
#   {'type': 'Feature',
#    'properties': {'ANN_CD': 30, 'ANN_NM': '도로'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[167355.3500000034, 560869.4767829783],
#       [167311.39852617204, 560858.6598714562],
#       [167268.53786615707, 560849.0424916383],
#       [167263.41823240294, 560874.3272134445],
#       [167266.74986363348, 560875.0146929026],
#       [167315.97787617304, 560886.7901643435],
#       [167355.3500000034, 560896.7748216459],
#       [167355.3500000034, 560869.4767829783]]]}},
#   {'type': 'Feature',
#    'properties': {'ANN_CD': 30, 'ANN_NM': '도로'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[167232.2098897133, 560792.150136266],
#       [167231.51453784498, 560792.150136266],
#       [167232.171604658, 560792.31215418],
#       [167232.2098897133, 560792.150136266]]]}},
#   {'type': 'Feature',
#    'properties': {'ANN_CD': 30, 'ANN_NM': '도로'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[167154.04332450373, 561053.2701362699],
#       [167163.74816858693, 561053.2701362699],
#       [167168.69251731853, 561033.4927413455],
#       [167159.05193732836, 561031.2834417624],
#       [167156.94402816583, 561040.6170668615],
#       [167154.04332450373, 561053.2701362699]]]}},
#   {'type': 'Feature',
#    'properties': {'ANN_CD': 30, 'ANN_NM': '도로'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[167139.43107513105, 561053.2701362699],
#       [167149.986078034, 561053.2701362699],
#       [167151.79541338675, 561044.9933894222],
#       [167155.2077740636, 561030.4024876856],
#       [167145.10299562346, 561028.0868092882],
#       [167139.43107513105, 561053.2701362699]]]}},
#   {'type': 'Feature',
#    'properties': {'ANN_CD': 30, 'ANN_NM': '도로'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[167151.3814842838, 560817.3351059853],
#       [167147.38869798701, 560816.550808672],
#       [167116.82791963933, 560809.0584888234],
#       [167094.22999999954, 560803.5183536848],
#       [167094.22999999954, 560832.890235196],
#       [167111.21893160755, 560836.9472934878],
#       [167132.70322893435, 560842.1144029722],
#       [167142.76549476813, 560844.5619811491],
#       [167145.33964067846, 560845.7177201264],
#       [167151.3814842838, 560817.3351059853]]]}},
#   {'type': 'Feature',
#    'properties': {'ANN_CD': 30, 'ANN_NM': '도로'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[167203.79187169985, 560906.0340402627],
#       [167175.10128924533, 560901.5093605908],
#       [167173.76815166767, 560906.9752246473],
#       [167168.73701875634, 560929.5473344962],
#       [167169.0089718802, 560942.0571785179],
#       [167166.34060284647, 560952.93948977],
#       [167148.2626734643, 561022.757699786],
#       [167156.94295102335, 561024.8278915096],
#       [167172.44046181696, 560965.0761798222],
#       [167181.01205046664, 560930.107994316],
#       [167181.79128580328, 560928.4521192313],
#       [167182.86273438114, 560928.062501574],
#       [167183.54456529737, 560928.3547148198],
#       [167184.1289917954, 560929.2313545701],
#       [167184.22639621136, 560930.2053987321],
#       [167175.84961639586, 560965.9528195747],
#       [167169.61573374274, 560990.2065192643],
#       [167160.5599219824, 561025.690516377],
#       [167170.70604669454, 561028.1103034427],
#       [167183.0570585789, 560978.4933074497],
#       [167184.76064642306, 560971.6789560687],
#       [167191.042626593, 560958.5826245089],
#       [167198.51588657184, 560928.3235454077],
#       [167197.97198030635, 560926.8278031909],
#       [167197.70002717583, 560925.6040141025],
#       [167197.70002717583, 560924.2442484454],
#       [167198.10795687052, 560923.2924124898],
#       [167198.92381626653, 560921.6606937088],
#       [167198.9238162643, 560920.300928054],
#       [167198.78783970015, 560918.5332327023],
#       [167198.9238162643, 560917.4454201846],
#       [167200.0116287886, 560916.2216310961],
#       [167200.69151160936, 560915.269795136],
#       [167203.68299604955, 560906.2953418199],
#       [167203.79187169985, 560906.0340402627]]]}},
#   {'type': 'Feature',
#    'properties': {'ANN_CD': 100, 'ANN_NM': '비대상지'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[167199.97451578872, 560792.150136266],
#       [167175.20775271166, 560792.150136266],
#       [167174.05255905495, 560796.6912423607],
#       [167153.8840144171, 560810.1369387897],
#       [167149.21105429117, 560809.1521290217],
#       [167146.14136993943, 560808.3792041454],
#       [167149.44776496303, 560795.4685188083],
#       [167144.3805187422, 560794.1042602079],
#       [167144.3805187422, 560792.150136266],
#       [167095.6468231578, 560792.150136266],
#       [167095.02321734745, 560795.50801371],
#       [167094.22999999954, 560795.3082871719],
#       [167094.22999999954, 560803.5183536848],
#       [167116.82791963933, 560809.0584888234],
#       [167147.38869798701, 560816.550808672],
#       [167151.3814842838, 560817.3351059853],
#       [167155.00338564828, 560818.0465508976],
#       [167159.75357574006, 560817.9239830318],
#       [167164.87684966277, 560817.4011999835],
#       [167169.79101035465, 560816.3556338736],
#       [167175.0188408795, 560814.264501674],
#       [167180.9785676768, 560811.5460297927],
#       [167188.92487008058, 560806.109086046],
#       [167192.16612500112, 560802.8678311276],
#       [167197.39395552597, 560796.5944344884],
#       [167199.97451578872, 560792.150136266]]]}},
#   {'type': 'Feature',
#    'properties': {'ANN_CD': 100, 'ANN_NM': '비대상지'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[167196.7971003383, 560823.754737756],
#       [167204.48205223153, 560797.6259013207],
#       [167197.6832576264, 560804.2939498723],
#       [167193.49938402273, 560809.131553728],
#       [167189.8384946198, 560811.8772207807],
#       [167186.3083512704, 560814.6228878313],
#       [167180.29403296413, 560817.7607930313],
#       [167176.11015936045, 560819.4604916803],
#       [167171.01106340438, 560821.0294442825],
#       [167166.95793585424, 560822.075412684],
#       [167162.77406225278, 560823.1213810855],
#       [167162.25467509497, 560824.2800139759],
#       [167186.49145251626, 560829.2782599016],
#       [167194.6760984755, 560830.9661440876],
#       [167196.7971003383, 560823.754737756]]]}},
#   {'type': 'Feature',
#    'properties': {'ANN_CD': 100, 'ANN_NM': '비대상지'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[167232.2922997351, 560821.0221152807],
#       [167225.97433590805, 560802.4755121925],
#       [167219.2563558879, 560829.004953336],
#       [167217.42591118976, 560835.6730018898],
#       [167217.5566572433, 560836.4574781931],
#       [167218.21038749086, 560837.6341926459],
#       [167219.12560984326, 560838.1571768422],
#       [167225.27067419636, 560839.333891295],
#       [167249.5243168551, 560844.776096181],
#       [167237.311098139, 560831.0597120863],
#       [167235.39917493856, 560827.7138464844],
#       [167232.2922997351, 560821.0221152807]]]}},
#   {'type': 'Feature',
#    'properties': {'ANN_CD': 100, 'ANN_NM': '비대상지'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[167232.2098897133, 560792.150136266],
#       [167232.171604658, 560792.31215418],
#       [167235.3991749408, 560813.8524032757],
#       [167236.35513654322, 560818.8712016819],
#       [167238.98403094328, 560824.6069712832],
#       [167243.76383894213, 560832.7326448906],
#       [167246.87071415008, 560836.0785104969],
#       [167252.12850295237, 560840.1413472962],
#       [167268.53786615707, 560849.0424916383],
#       [167311.39852617204, 560858.6598714562],
#       [167355.3500000034, 560869.4767829783],
#       [167355.3500000034, 560792.150136266],
#       [167232.2098897133, 560792.150136266]],
#      [[167322.8489230154, 560836.7208120805],
#       [167316.80407527077, 560838.2728675863],
#       [167309.1254848922, 560831.6562099203],
#       [167310.10573047213, 560830.3492158123],
#       [167308.71704923152, 560829.1239088346],
#       [167304.79606691631, 560832.9632040261],
#       [167298.83290630204, 560827.0000434185],
#       [167302.75388862166, 560823.0790611011],
#       [167302.2637658284, 560822.425564036],
#       [167301.2018331159, 560823.4058096203],
#       [167294.91192398462, 560817.5243361408],
#       [167296.46397948152, 560815.8089063744],
#       [167294.5851754565, 560814.0934766122],
#       [167291.8078129775, 560816.7074648172],
#       [167291.56275157974, 560819.4031401725],
#       [167285.35452957882, 560826.1014849667],
#       [167278.57449764758, 560827.4901662095],
#       [167272.0508035167, 560821.4628401108],
#       [167271.75339560368, 560818.6519574972],
#       [167277.43096556852, 560813.4547986492],
#       [167289.84732181768, 560799.6348542981],
#       [167298.3427835132, 560798.4095473225],
#       [167329.3022064185, 560828.9605345783],
#       [167322.8489230154, 560836.7208120805]]]}},
#   {'type': 'Feature',
#    'properties': {'ANN_CD': 100, 'ANN_NM': '비대상지'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[167181.4619720925, 560851.8142010425],
#       [167151.19604181653, 560843.7461217464],
#       [167159.35463573664, 560849.1851843613],
#       [167165.47358118117, 560854.4882704099],
#       [167169.6888547076, 560860.063309591],
#       [167171.0486203602, 560861.8310049406],
#       [167174.17608136233, 560866.4542081617],
#       [167176.35170641096, 560871.3493645155],
#       [167179.3431908467, 560880.4597943936],
#       [167180.83893306568, 560888.6183883159],
#       [167181.62648472408, 560888.8374115597],
#       [167187.37853331747, 560863.6168907948],
#       [167189.57700251942, 560853.9774489023],
#       [167181.4619720925, 560851.8142010425]]]}},
#   {'type': 'Feature',
#    'properties': {'ANN_CD': 100, 'ANN_NM': '비대상지'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[167220.9560545392, 560861.2992277081],
#       [167215.59546648496, 560860.5147514071],
#       [167214.2880059898, 560860.9069895587],
#       [167213.11129153924, 560861.5607198152],
#       [167212.457561285, 560862.6066882123],
#       [167212.06532313555, 560863.7834026605],
#       [167210.7578626337, 560868.7517525653],
#       [167205.38350820102, 560889.0889096056],
#       [167211.73912532264, 560882.2036577213],
#       [167219.8647989278, 560876.7068785205],
#       [167225.36157813072, 560874.3169745189],
#       [167233.96523253713, 560870.971108917],
#       [167240.17898293966, 560869.0591857143],
#       [167252.5820532714, 560868.6215018841],
#       [167220.9560545392, 560861.2992277081]]]}},
#   {'type': 'Feature',
#    'properties': {'ANN_CD': 100, 'ANN_NM': '비대상지'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[167355.3500000034, 561020.6249100823],
#       [167355.3500000034, 561019.6463796619],
#       [167354.76795464545, 561019.869103472],
#       [167355.3500000034, 561020.6249100823]]]}},
#   {'type': 'Feature',
#    'properties': {'ANN_CD': 100, 'ANN_NM': '비대상지'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[167355.3500000034, 561053.2701362699],
#       [167355.3500000034, 561051.5041432474],
#       [167353.29703478861, 561048.7912963531],
#       [167351.6600558057, 561049.814408213],
#       [167348.48840903738, 561045.8242719576],
#       [167350.33001038874, 561044.3919153477],
#       [167348.79534259223, 561042.7549363713],
#       [167352.47854529938, 561040.0948455308],
#       [167352.27392292206, 561039.0717336687],
#       [167349.920765643, 561039.5832896008],
#       [167345.7260070126, 561034.3654191105],
#       [167344.9075175189, 561034.7746638496],
#       [167345.7260070126, 561036.6162652076],
#       [167343.34707305866, 561037.7990700483],
#       [167339.0710262581, 561040.8601027783],
#       [167340.6351471989, 561043.0090667136],
#       [167336.7549615332, 561046.1600408434],
#       [167329.45852841862, 561052.1675654965],
#       [167322.6036789454, 561044.903471282],
#       [167330.11112963877, 561038.3522328055],
#       [167333.90806349248, 561035.0740698952],
#       [167331.60706332483, 561028.6359926836],
#       [167330.3793290854, 561029.1475486158],
#       [167328.23079418365, 561023.1111886295],
#       [167330.68626264913, 561018.2002516985],
#       [167333.76398862022, 561016.644131006],
#       [167339.84911125764, 561014.5149691848],
#       [167340.93708294808, 561017.2949531376],
#       [167355.3500000034, 561012.3065894635],
#       [167355.3500000034, 560896.7748216459],
#       [167315.97787617304, 560886.7901643435],
#       [167266.74986363348, 560875.0146929026],
#       [167263.41823240294, 560874.3272134445],
#       [167256.4463261224, 560872.8885661135],
#       [167252.74010115582, 560872.8887947166],
#       [167240.89595414372, 560873.361012921],
#       [167234.68220373895, 560875.2729361169],
#       [167231.81431893609, 560876.2288977216],
#       [167226.31753973538, 560878.8577921238],
#       [167222.25470292947, 560881.72567692],
#       [167215.32398132954, 560887.2224561252],
#       [167207.30536615534, 560897.7709636857],
#       [167207.0824101844, 560898.1367479042],
#       [167203.79187169985, 560906.0340402627],
#       [167203.68299604955, 560906.2953418199],
#       [167200.69151160936, 560915.269795136],
#       [167200.0116287886, 560916.2216310961],
#       [167198.9238162643, 560917.4454201846],
#       [167198.78783970015, 560918.5332327023],
#       [167198.9238162643, 560920.300928054],
#       [167198.92381626653, 560921.6606937088],
#       [167198.10795687052, 560923.2924124898],
#       [167197.70002717583, 560924.2442484454],
#       [167197.70002717583, 560925.6040141025],
#       [167197.97198030635, 560926.8278031909],
#       [167198.51588657184, 560928.3235454077],
#       [167191.042626593, 560958.5826245089],
#       [167184.76064642306, 560971.6789560687],
#       [167183.0570585789, 560978.4933074497],
#       [167170.70604669454, 561028.1103034427],
#       [167160.5599219824, 561025.690516377],
#       [167169.61573374274, 560990.2065192643],
#       [167175.84961639586, 560965.9528195747],
#       [167184.22639621136, 560930.2053987321],
#       [167184.1289917954, 560929.2313545701],
#       [167183.54456529737, 560928.3547148198],
#       [167182.86273438114, 560928.062501574],
#       [167181.79128580328, 560928.4521192313],
#       [167181.01205046664, 560930.107994316],
#       [167172.44046181696, 560965.0761798222],
#       [167156.94295102335, 561024.8278915096],
#       [167148.2626734643, 561022.757699786],
#       [167166.34060284647, 560952.93948977],
#       [167169.0089718802, 560942.0571785179],
#       [167168.73701875634, 560929.5473344962],
#       [167173.76815166767, 560906.9752246473],
#       [167175.10128924533, 560901.5093605908],
#       [167176.48768297955, 560895.825146287],
#       [167176.75963610783, 560890.3860836765],
#       [167175.3998704597, 560881.1396772255],
#       [167172.95229228275, 560874.204872396],
#       [167166.96932340015, 560863.8706534251],
#       [167162.07416705298, 560857.343778297],
#       [167155.95522161067, 560852.0406922395],
#       [167149.42834647148, 560847.5534655827],
#       [167145.33964067846, 560845.7177201264],
#       [167142.76549476813, 560844.5619811491],
#       [167132.70322893435, 560842.1144029722],
#       [167111.21893160755, 560836.9472934878],
#       [167094.22999999954, 560832.890235196],
#       [167094.22999999954, 560956.6269933472],
#       [167102.56995688187, 560951.4585693647],
#       [167104.65630425475, 560948.9858613648],
#       [167102.78113830625, 560947.4650850107],
#       [167115.78402664047, 560931.4960474982],
#       [167127.61010391888, 560941.1291482951],
#       [167124.39602387964, 560945.1307795263],
#       [167132.54240729476, 560951.2607314016],
#       [167131.84997444483, 560954.4261387099],
#       [167126.1126737088, 560962.1418190153],
#       [167124.03537515897, 560961.6472241218],
#       [167124.6288890351, 560964.515874491],
#       [167138.97214088298, 560980.540748969],
#       [167131.65213649056, 560985.3877789052],
#       [167128.18997224973, 560981.0353438625],
#       [167125.61807881534, 560982.5191285361],
#       [167122.05012786016, 560981.664090976],
#       [167119.2089874192, 560978.2019899201],
#       [167117.97512162945, 560979.2890673159],
#       [167113.28496253848, 560973.4710114154],
#       [167105.438607251, 560977.3753416651],
#       [167104.94401235756, 560975.8915569914],
#       [167101.58076709943, 560977.4742606434],
#       [167094.22999999954, 560974.344726133],
#       [167094.22999999954, 561053.2701362699],
#       [167139.43107513105, 561053.2701362699],
#       [167145.10299562346, 561028.0868092882],
#       [167155.2077740636, 561030.4024876856],
#       [167151.79541338675, 561044.9933894222],
#       [167149.986078034, 561053.2701362699],
#       [167154.04332450373, 561053.2701362699],
#       [167156.94402816583, 561040.6170668615],
#       [167159.05193732836, 561031.2834417624],
#       [167168.69251731853, 561033.4927413455],
#       [167163.74816858693, 561053.2701362699],
#       [167355.3500000034, 561053.2701362699]],
#      [[167139.667088201, 560910.4451189712],
#       [167136.87514719143, 560906.9830137955],
#       [167135.54008106675, 560908.0700849127],
#       [167130.8500214682, 560902.252029814],
#       [167132.18906786534, 560901.2031269942],
#       [167130.61707684185, 560899.377035644],
#       [167129.88396855313, 560900.0550365637],
#       [167122.45721221785, 560903.899177033],
#       [167121.49486722695, 560902.2494427552],
#       [167117.37053153935, 560904.4490884523],
#       [167110.10608116153, 560901.5020902543],
#       [167106.35507616375, 560894.6069910957],
#       [167107.66205699072, 560893.9060407782],
#       [167106.9911413878, 560892.7792325799],
#       [167111.16711855764, 560890.4528607074],
#       [167111.02207801936, 560890.1880939584],
#       [167116.35098333095, 560887.2200382691],
#       [167116.6459748314, 560887.8450982528],
#       [167121.83601482926, 560884.9551302389],
#       [167125.67502391397, 560880.3230123289],
#       [167125.07212533953, 560879.8731065515],
#       [167128.96613178935, 560875.1171041923],
#       [167129.10000803004, 560875.3060174391],
#       [167132.1562470495, 560871.6141280464],
#       [167133.10199448065, 560872.4221206134],
#       [167134.05695088927, 560871.3082479902],
#       [167143.07889066264, 560873.6540486393],
#       [167149.5403499126, 560879.1531629006],
#       [167141.15420067863, 560889.6014799795],
#       [167155.4518977344, 560906.7862120101],
#       [167147.8906156393, 560912.9727155493],
#       [167139.667088201, 560910.4451189712]],
#      [[167235.44832668253, 561022.3768373806],
#       [167232.52434719505, 561022.288231944],
#       [167229.1573405087, 561017.7693545566],
#       [167227.82825892328, 561018.744014382],
#       [167224.72706855802, 561014.9339805035],
#       [167226.2333610212, 561013.9593206714],
#       [167224.99288487688, 561012.3644227649],
#       [167229.24594594535, 561008.7315997664],
#       [167228.18268068103, 561007.4025181831],
#       [167226.76499365893, 561007.9341508164],
#       [167224.1479811599, 561004.2108538988],
#       [167218.6342404408, 561008.959122073],
#       [167220.34899553633, 561010.861067898],
#       [167216.34400334957, 561014.3870425394],
#       [167215.95596410587, 561013.9490865096],
#       [167212.87296543794, 561016.5209695457],
#       [167205.5882937199, 561022.3768373806],
#       [167198.4998585917, 561013.9593206714],
#       [167210.28438198945, 561004.5671441323],
#       [167207.892035133, 560997.6559198863],
#       [167206.82876986422, 560998.0103416418],
#       [167204.17060669116, 560990.8333010792],
#       [167205.1452665255, 560988.6181651028],
#       [167213.33808564203, 560984.8221396599],
#       [167219.2311458744, 560982.8539786482],
#       [167220.0460842025, 560985.2279632568],
#       [167231.37610642423, 560981.2830740884],
#       [167231.6539914273, 560982.0771029466],
#       [167237.0860169526, 560979.6189777546],
#       [167239.56011861726, 560986.0289688446],
#       [167234.6110418231, 560987.9350046684],
#       [167235.0362410257, 560988.9580333263],
#       [167238.44804530405, 560992.952864788],
#       [167238.82797794006, 560992.803136308],
#       [167242.28295721186, 560997.0340480445],
#       [167242.0520826846, 560997.2390904585],
#       [167245.7649920909, 561001.3280599248],
#       [167246.52912252743, 561000.6071426548],
#       [167252.3109792602, 561007.5150700741],
#       [167251.4550368271, 561008.3822499528],
#       [167252.1220455698, 561009.1789533957],
#       [167250.6300716194, 561010.4600907428],
#       [167251.12695805245, 561011.11497087],
#       [167247.45106380593, 561014.375072175],
#       [167240.67604758314, 561019.718674212],
#       [167239.61278231879, 561018.5668034998],
#       [167235.44832668253, 561022.3768373806]],
#      [[167291.54433339156, 560953.183123925],
#       [167303.61639794608, 560941.516843051],
#       [167300.37012848974, 560935.7344255822],
#       [167298.74699375936, 560936.2416551859],
#       [167296.00795390236, 560930.662129542],
#       [167296.71807533968, 560927.3144141666],
#       [167301.02000222076, 560925.593976296],
#       [167306.99211027566, 560922.8152484024],
#       [167308.09408295064, 560925.4800994821],
#       [167324.44798793978, 560918.4080040146],
#       [167327.33608573672, 560924.7371393994],
#       [167322.57099769614, 560926.8760058968],
#       [167327.0509947526, 560931.9380082816],
#       [167327.3140790117, 560931.4959862899],
#       [167330.94207278514, 560934.9630827528],
#       [167330.52697838063, 560935.366013729],
#       [167334.48300476928, 560939.4151311666],
#       [167335.46202234458, 560938.4978563247],
#       [167341.71009084652, 560945.1720854511],
#       [167340.7491312696, 560946.1359730588],
#       [167341.44411208347, 560946.8051138818],
#       [167340.02024448663, 560948.2430364601],
#       [167340.60909014937, 560948.8178782534],
#       [167337.24800457526, 560952.1381454841],
#       [167336.49101220875, 560951.2539650323],
#       [167331.97995581533, 560955.4680212989],
#       [167331.45824807286, 560954.8750972905],
#       [167330.47312347498, 560955.7490913301],
#       [167327.55763520833, 560958.661203639],
#       [167322.99256878518, 560953.6903535288],
#       [167321.6737718162, 560954.7048127365],
#       [167318.32605643198, 560951.7628810349],
#       [167319.74629931996, 560949.9368544642],
#       [167317.81882682818, 560948.4151656551],
#       [167321.87666365417, 560944.6616665905],
#       [167320.86220445542, 560943.6472073828],
#       [167319.13762379717, 560944.6616665905],
#       [167316.68074947194, 560941.0159820998],
#       [167315.30307985898, 560941.6179725076],
#       [167313.41506898188, 560943.3300525164],
#       [167311.4541040348, 560944.9911256599],
#       [167311.89300661522, 560945.5640677403],
#       [167308.45498173495, 560949.0179722926],
#       [167310.13498484032, 560950.9340709016],
#       [167306.45287062673, 560954.6699747348],
#       [167306.06101160037, 560954.2950871632],
#       [167303.08405468304, 560957.2039552632],
#       [167299.1527774353, 560960.5886761287],
#       [167291.54433339156, 560953.183123925]],
#      [[167252.04824081488, 560916.9412459965],
#       [167262.10399252176, 560928.4099989003],
#       [167262.83914319478, 560927.7550840958],
#       [167269.6060058754, 560935.9970003574],
#       [167268.66724444617, 560936.9560715902],
#       [167269.35596500337, 560937.9021436654],
#       [167267.87812527452, 560939.1590478806],
#       [167268.29999997563, 560939.8520081994],
#       [167264.7811187794, 560942.5980306603],
#       [167264.05198388055, 560941.598990874],
#       [167258.8738596837, 560945.4591001828],
#       [167258.49023651986, 560945.1001285907],
#       [167257.5760913255, 560945.6891326135],
#       [167250.92354804897, 560950.301159262],
#       [167246.22596792597, 560944.916128395],
#       [167244.85106642707, 560945.9473045209],
#       [167241.87211318495, 560942.3954756503],
#       [167243.81989030787, 560940.5622736474],
#       [167242.33041368236, 560938.9582219041],
#       [167247.37171917842, 560935.0626676605],
#       [167246.22596792597, 560933.8023412793],
#       [167243.7053151835, 560935.5209681579],
#       [167241.54596520928, 560932.297961377],
#       [167236.10803192388, 560936.9561020677],
#       [167237.6860067826, 560939.1609599106],
#       [167233.55495737024, 560942.6859964053],
#       [167233.26401963894, 560942.5081494094],
#       [167230.33012391775, 560945.0739915817],
#       [167222.6234922111, 560949.4991333914],
#       [167214.946958846, 560941.7080248976],
#       [167227.66479770272, 560931.396263659],
#       [167222.6234922111, 560919.7096009281],
#       [167224.57126933403, 560915.5848964335],
#       [167230.62204339448, 560913.2440587617],
#       [167236.64699565776, 560911.251958025],
#       [167237.4061213927, 560913.7559913207],
#       [167248.6602416809, 560909.7280008227],
#       [167248.91824949626, 560910.3850751801],
#       [167254.68312194844, 560908.2559734501],
#       [167256.9509757456, 560914.6271180671],
#       [167252.15199401972, 560916.1091373109],
#       [167252.04824081488, 560916.9412459965]]]}}]}

# %%
label1.keys()
# Out:
# dict_keys(['type', 'name', 'crs', 'features'])

# %% [markdown]
# Since we are making an image segmentation task, the important information isontained in 'features'.
# Here is an example of the 1st feature.

# %%
feature1 = label1['features'][0]
feature1
# Out:
# {'type': 'Feature',
#  'properties': {'ANN_CD': 10, 'ANN_NM': '건물'},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[167095.6468231578, 560792.150136266],
#     [167094.22999999954, 560792.150136266],
#     [167094.22999999954, 560795.3082871719],
#     [167095.02321734745, 560795.50801371],
#     [167095.6468231578, 560792.150136266]]]}}

# %% [markdown]
# This tells us the type of object labelled in the picture:

# %%
feature1['properties']['ANN_NM']
# Out:
# '건물'

# %% [markdown]
# '건물' is korean for 'building'.

# %% [markdown]
# Instead, we can use 'ANN_CD', which stands for annotation code. 10 corresponds to 'buildings'.

# %% [markdown]
# The following tells us the polygon coordinates for the given feature (i.e. the building):

# %%
feature1['geometry']['coordinates']
# Out:
# [[[167095.6468231578, 560792.150136266],
#   [167094.22999999954, 560792.150136266],
#   [167094.22999999954, 560795.3082871719],
#   [167095.02321734745, 560795.50801371],
#   [167095.6468231578, 560792.150136266]]]

# %% [markdown]
# For images that are of size (512,512), these coordinates seem unreasonably large. We check the meta files for more information.

# %% [markdown]
# ### META files

# %%
meta1_path = os.path.join(metafiles_path, meta_files[0])
meta1 = json.load(open(meta1_path))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Input In [23], in <cell line: 2>()
#       1 meta1_path = os.path.join(metafiles_path, meta_files[0])
# ----> 2 meta1 = json.load(open(meta1_path))
#
# File /usr/lib/python3.9/json/__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File /usr/lib/python3.9/codecs.py:322, in BufferedIncrementalDecoder.decode(self, input, final)
#     319 def decode(self, input, final=False):
#     320     # decode input (taking the buffer into account)
#     321     data = self.buffer + input
# --> 322     (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323     # keep undecoded input until the next call
#     324     self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb1 in position 269: invalid start byte

# %% [markdown]
# There seems to be invalid bytes in our files. We use *iconv* to fix this:
# ```
# find -type f -exec iconv -f utf-8 -c {} -o $/path/to/output/directory/{} \;
# ```

# %% [markdown]
# In our actual project, we run the bash script *fix_utf.sh* to create fixed versions of the META files.

# %% [markdown]
# #### Example with 1 file

# %%
# New path containing the corrected meta files
metafiles_path = '/workspace/Competition/map_segmentation/data/RAW/train/meta_fixed'
meta_files = os.listdir(metafiles_path)
len(meta_files)
# Out:
# 13520

# %%
meta1_path = os.path.join(metafiles_path, meta_files[0])
meta1 = json.load(open(meta1_path))

# %%
meta1
# Out:
# [{'img_id': 'LC_AP_37607046_068',
#   'img_width': 512,
#   'img_height': 512,
#   'img_type': 'aerophoto',
#   'img_coordinate': 'EPSG:5186',
#   'coordinates': '168465.365000002, 559877.975136267',
#   'img_resolution': 0.51,
#   'img_time': 2018,
#   'img_provided': '',
#   'ann_id': 'LC_AP_37607046_068_FGT',
#   'ann_type': 'polygon',
#   'ann_file_type': 'tif',
#   'provided_nm': 'ѱȸ'}]

# %% [markdown]
# Of the information provided in the meta files, 'img_coordinate' and 'coordinates' are the most important.

# %% [markdown]
# ### Drawing polygons onto the images

# %% [markdown]
# As an example, we plot single features onto one image.

# %%
rawtiff_names[0]
# Out:
# 'LC_AP_37607046_001'

# %%
# File names
f_id = rawtiff_names[0]
tiff_id = f_id+'.tif'
label_id = f_id + '_FGT.json'
meta_id = f_id + '_META.json'

# File paths
impath = os.path.join(rawtiffs_path, tiff_id)
labelpath = os.path.join(labeljsons_path, label_id)
metapath = os.path.join(metafiles_path, meta_id)

# Load image and files
im = tiff.imread(impath)
label_dict = json.load(open(labelpath))
meta_dict = json.load(open(metapath))

# %%
label_dict['features']
# Out:
# [{'type': 'Feature',
#   'properties': {'ANN_CD': 10, 'ANN_NM': '건물'},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[167095.6468231578, 560792.150136266],
#      [167094.22999999954, 560792.150136266],
#      [167094.22999999954, 560795.3082871719],
#      [167095.02321734745, 560795.50801371],
#      [167095.6468231578, 560792.150136266]]]}},
#  {'type': 'Feature',
#   'properties': {'ANN_CD': 10, 'ANN_NM': '건물'},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[167175.20775271166, 560792.150136266],
#      [167144.3805187422, 560792.150136266],
#      [167144.3805187422, 560794.1042602079],
#      [167149.44776496303, 560795.4685188083],
#      [167146.14136993943, 560808.3792041454],
#      [167149.21105429117, 560809.1521290217],
#      [167153.8840144171, 560810.1369387897],
#      [167174.05255905495, 560796.6912423607],
#      [167175.20775271166, 560792.150136266]]]}},
#  {'type': 'Feature',
#   'properties': {'ANN_CD': 10, 'ANN_NM': '건물'},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[167322.8489230154, 560836.7208120805],
#      [167329.3022064185, 560828.9605345783],
#      [167298.3427835132, 560798.4095473225],
#      [167289.84732181768, 560799.6348542981],
#      [167277.43096556852, 560813.4547986492],
#      [167271.75339560368, 560818.6519574972],
#      [167272.0508035167, 560821.4628401108],
#      [167278.57449764758, 560827.4901662095],
#      [167285.35452957882, 560826.1014849667],
#      [167291.56275157974, 560819.4031401725],
#      [167291.8078129775, 560816.7074648172],
#      [167294.5851754565, 560814.0934766122],
#      [167296.46397948152, 560815.8089063744],
#      [167294.91192398462, 560817.5243361408],
#      [167301.2018331159, 560823.4058096203],
#      [167302.2637658284, 560822.425564036],
#      [167302.75388862166, 560823.0790611011],
#      [167298.83290630204, 560827.0000434185],
#      [167304.79606691631, 560832.9632040261],
#      [167308.71704923152, 560829.1239088346],
#      [167310.10573047213, 560830.3492158123],
#      [167309.1254848922, 560831.6562099203],
#      [167316.80407527077, 560838.2728675863],
#      [167322.8489230154, 560836.7208120805]]]}},
#  {'type': 'Feature',
#   'properties': {'ANN_CD': 10, 'ANN_NM': '건물'},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[167147.8906156393, 560912.9727155493],
#      [167155.4518977344, 560906.7862120101],
#      [167141.15420067863, 560889.6014799795],
#      [167149.5403499126, 560879.1531629006],
#      [167143.07889066264, 560873.6540486393],
#      [167134.05695088927, 560871.3082479902],
#      [167133.10199448065, 560872.4221206134],
#      [167132.1562470495, 560871.6141280464],
#      [167129.10000803004, 560875.3060174391],
#      [167128.96613178935, 560875.1171041923],
#      [167125.07212533953, 560879.8731065515],
#      [167125.67502391397, 560880.3230123289],
#      [167121.83601482926, 560884.9551302389],
#      [167116.6459748314, 560887.8450982528],
#      [167116.35098333095, 560887.2200382691],
#      [167111.02207801936, 560890.1880939584],
#      [167111.16711855764, 560890.4528607074],
#      [167106.9911413878, 560892.7792325799],
#      [167107.66205699072, 560893.9060407782],
#      [167106.35507616375, 560894.6069910957],
#      [167110.10608116153, 560901.5020902543],
#      [167117.37053153935, 560904.4490884523],
#      [167121.49486722695, 560902.2494427552],
#      [167122.45721221785, 560903.899177033],
#      [167129.88396855313, 560900.0550365637],
#      [167130.61707684185, 560899.377035644],
#      [167132.18906786534, 560901.2031269942],
#      [167130.8500214682, 560902.252029814],
#      [167135.54008106675, 560908.0700849127],
#      [167136.87514719143, 560906.9830137955],
#      [167139.667088201, 560910.4451189712],
#      [167147.8906156393, 560912.9727155493]]]}},
#  {'type': 'Feature',
#   'properties': {'ANN_CD': 10, 'ANN_NM': '건물'},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[167257.5760913255, 560945.6891326135],
#      [167258.49023651986, 560945.1001285907],
#      [167258.8738596837, 560945.4591001828],
#      [167264.05198388055, 560941.598990874],
#      [167264.7811187794, 560942.5980306603],
#      [167268.29999997563, 560939.8520081994],
#      [167267.87812527452, 560939.1590478806],
#      [167269.35596500337, 560937.9021436654],
#      [167268.66724444617, 560936.9560715902],
#      [167269.6060058754, 560935.9970003574],
#      [167262.83914319478, 560927.7550840958],
#      [167262.10399252176, 560928.4099989003],
#      [167252.04824081488, 560916.9412459965],
#      [167252.15199401972, 560916.1091373109],
#      [167256.9509757456, 560914.6271180671],
#      [167254.68312194844, 560908.2559734501],
#      [167248.91824949626, 560910.3850751801],
#      [167248.6602416809, 560909.7280008227],
#      [167237.4061213927, 560913.7559913207],
#      [167236.64699565776, 560911.251958025],
#      [167230.62204339448, 560913.2440587617],
#      [167224.57126933403, 560915.5848964335],
#      [167222.6234922111, 560919.7096009281],
#      [167227.66479770272, 560931.396263659],
#      [167214.946958846, 560941.7080248976],
#      [167222.6234922111, 560949.4991333914],
#      [167230.33012391775, 560945.0739915817],
#      [167233.26401963894, 560942.5081494094],
#      [167233.55495737024, 560942.6859964053],
#      [167237.6860067826, 560939.1609599106],
#      [167236.10803192388, 560936.9561020677],
#      [167241.54596520928, 560932.297961377],
#      [167243.7053151835, 560935.5209681579],
#      [167246.22596792597, 560933.8023412793],
#      [167247.37171917842, 560935.0626676605],
#      [167242.33041368236, 560938.9582219041],
#      [167243.81989030787, 560940.5622736474],
#      [167241.87211318495, 560942.3954756503],
#      [167244.85106642707, 560945.9473045209],
#      [167246.22596792597, 560944.916128395],
#      [167250.92354804897, 560950.301159262],
#      [167257.5760913255, 560945.6891326135]]]}},
#  {'type': 'Feature',
#   'properties': {'ANN_CD': 10, 'ANN_NM': '건물'},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[167303.08405468304, 560957.2039552632],
#      [167306.06101160037, 560954.2950871632],
#      [167306.45287062673, 560954.6699747348],
#      [167310.13498484032, 560950.9340709016],
#      [167308.45498173495, 560949.0179722926],
#      [167311.89300661522, 560945.5640677403],
#      [167311.4541040348, 560944.9911256599],
#      [167313.41506898188, 560943.3300525164],
#      [167315.30307985898, 560941.6179725076],
#      [167316.68074947194, 560941.0159820998],
#      [167319.13762379717, 560944.6616665905],
#      [167320.86220445542, 560943.6472073828],
#      [167321.87666365417, 560944.6616665905],
#      [167317.81882682818, 560948.4151656551],
#      [167319.74629931996, 560949.9368544642],
#      [167318.32605643198, 560951.7628810349],
#      [167321.6737718162, 560954.7048127365],
#      [167322.99256878518, 560953.6903535288],
#      [167327.55763520833, 560958.661203639],
#      [167330.47312347498, 560955.7490913301],
#      [167331.45824807286, 560954.8750972905],
#      [167331.97995581533, 560955.4680212989],
#      [167336.49101220875, 560951.2539650323],
#      [167337.24800457526, 560952.1381454841],
#      [167340.60909014937, 560948.8178782534],
#      [167340.02024448663, 560948.2430364601],
#      [167341.44411208347, 560946.8051138818],
#      [167340.7491312696, 560946.1359730588],
#      [167341.71009084652, 560945.1720854511],
#      [167335.46202234458, 560938.4978563247],
#      [167334.48300476928, 560939.4151311666],
#      [167330.52697838063, 560935.366013729],
#      [167330.94207278514, 560934.9630827528],
#      [167327.3140790117, 560931.4959862899],
#      [167327.0509947526, 560931.9380082816],
#      [167322.57099769614, 560926.8760058968],
#      [167327.33608573672, 560924.7371393994],
#      [167324.44798793978, 560918.4080040146],
#      [167308.09408295064, 560925.4800994821],
#      [167306.99211027566, 560922.8152484024],
#      [167301.02000222076, 560925.593976296],
#      [167296.71807533968, 560927.3144141666],
#      [167296.00795390236, 560930.662129542],
#      [167298.74699375936, 560936.2416551859],
#      [167300.37012848974, 560935.7344255822],
#      [167303.61639794608, 560941.516843051],
#      [167291.54433339156, 560953.183123925],
#      [167299.1527774353, 560960.5886761287],
#      [167303.08405468304, 560957.2039552632]]]}},
#  {'type': 'Feature',
#   'properties': {'ANN_CD': 10, 'ANN_NM': '건물'},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[167094.22999999954, 560956.6269933472],
#      [167094.22999999954, 560974.344726133],
#      [167101.58076709943, 560977.4742606434],
#      [167104.94401235756, 560975.8915569914],
#      [167105.438607251, 560977.3753416651],
#      [167113.28496253848, 560973.4710114154],
#      [167117.97512162945, 560979.2890673159],
#      [167119.2089874192, 560978.2019899201],
#      [167122.05012786016, 560981.664090976],
#      [167125.61807881534, 560982.5191285361],
#      [167128.18997224973, 560981.0353438625],
#      [167131.65213649056, 560985.3877789052],
#      [167138.97214088298, 560980.540748969],
#      [167124.6288890351, 560964.515874491],
#      [167124.03537515897, 560961.6472241218],
#      [167126.1126737088, 560962.1418190153],
#      [167131.84997444483, 560954.4261387099],
#      [167132.54240729476, 560951.2607314016],
#      [167124.39602387964, 560945.1307795263],
#      [167127.61010391888, 560941.1291482951],
#      [167115.78402664047, 560931.4960474982],
#      [167102.78113830625, 560947.4650850107],
#      [167104.65630425475, 560948.9858613648],
#      [167102.56995688187, 560951.4585693647],
#      [167094.22999999954, 560956.6269933472]]]}},
#  {'type': 'Feature',
#   'properties': {'ANN_CD': 10, 'ANN_NM': '건물'},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[167235.44832668253, 561022.3768373806],
#      [167239.61278231879, 561018.5668034998],
#      [167240.67604758314, 561019.718674212],
#      [167247.45106380593, 561014.375072175],
#      [167251.12695805245, 561011.11497087],
#      [167250.6300716194, 561010.4600907428],
#      [167252.1220455698, 561009.1789533957],
#      [167251.4550368271, 561008.3822499528],
#      [167252.3109792602, 561007.5150700741],
#      [167246.52912252743, 561000.6071426548],
#      [167245.7649920909, 561001.3280599248],
#      [167242.0520826846, 560997.2390904585],
#      [167242.28295721186, 560997.0340480445],
#      [167238.82797794006, 560992.803136308],
#      [167238.44804530405, 560992.952864788],
#      [167235.0362410257, 560988.9580333263],
#      [167234.6110418231, 560987.9350046684],
#      [167239.56011861726, 560986.0289688446],
#      [167237.0860169526, 560979.6189777546],
#      [167231.6539914273, 560982.0771029466],
#      [167231.37610642423, 560981.2830740884],
#      [167220.0460842025, 560985.2279632568],
#      [167219.2311458744, 560982.8539786482],
#      [167213.33808564203, 560984.8221396599],
#      [167205.1452665255, 560988.6181651028],
#      [167204.17060669116, 560990.8333010792],
#      [167206.82876986422, 560998.0103416418],
#      [167207.892035133, 560997.6559198863],
#      [167210.28438198945, 561004.5671441323],
#      [167198.4998585917, 561013.9593206714],
#      [167205.5882937199, 561022.3768373806],
#      [167212.87296543794, 561016.5209695457],
#      [167215.95596410587, 561013.9490865096],
#      [167216.34400334957, 561014.3870425394],
#      [167220.34899553633, 561010.861067898],
#      [167218.6342404408, 561008.959122073],
#      [167224.1479811599, 561004.2108538988],
#      [167226.76499365893, 561007.9341508164],
#      [167228.18268068103, 561007.4025181831],
#      [167229.24594594535, 561008.7315997664],
#      [167224.99288487688, 561012.3644227649],
#      [167226.2333610212, 561013.9593206714],
#      [167224.72706855802, 561014.9339805035],
#      [167227.82825892328, 561018.744014382],
#      [167229.1573405087, 561017.7693545566],
#      [167232.52434719505, 561022.288231944],
#      [167235.44832668253, 561022.3768373806]]]}},
#  {'type': 'Feature',
#   'properties': {'ANN_CD': 10, 'ANN_NM': '건물'},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[167355.3500000034, 561051.5041432474],
#      [167355.3500000034, 561020.6249100823],
#      [167354.76795464545, 561019.869103472],
#      [167355.3500000034, 561019.6463796619],
#      [167355.3500000034, 561012.3065894635],
#      [167340.93708294808, 561017.2949531376],
#      [167339.84911125764, 561014.5149691848],
#      [167333.76398862022, 561016.644131006],
#      [167330.68626264913, 561018.2002516985],
#      [167328.23079418365, 561023.1111886295],
#      [167330.3793290854, 561029.1475486158],
#      [167331.60706332483, 561028.6359926836],
#      [167333.90806349248, 561035.0740698952],
#      [167330.11112963877, 561038.3522328055],
#      [167322.6036789454, 561044.903471282],
#      [167329.45852841862, 561052.1675654965],
#      [167336.7549615332, 561046.1600408434],
#      [167340.6351471989, 561043.0090667136],
#      [167339.0710262581, 561040.8601027783],
#      [167343.34707305866, 561037.7990700483],
#      [167345.7260070126, 561036.6162652076],
#      [167344.9075175189, 561034.7746638496],
#      [167345.7260070126, 561034.3654191105],
#      [167349.920765643, 561039.5832896008],
#      [167352.27392292206, 561039.0717336687],
#      [167352.47854529938, 561040.0948455308],
#      [167348.79534259223, 561042.7549363713],
#      [167350.33001038874, 561044.3919153477],
#      [167348.48840903738, 561045.8242719576],
#      [167351.6600558057, 561049.814408213],
#      [167353.29703478861, 561048.7912963531],
#      [167355.3500000034, 561051.5041432474]]]}},
#  {'type': 'Feature',
#   'properties': {'ANN_CD': 30, 'ANN_NM': '도로'},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[167263.41823240294, 560874.3272134445],
#      [167268.53786615707, 560849.0424916383],
#      [167252.12850295237, 560840.1413472962],
#      [167246.87071415008, 560836.0785104969],
#      [167243.76383894213, 560832.7326448906],
#      [167238.98403094328, 560824.6069712832],
#      [167236.35513654322, 560818.8712016819],
#      [167235.3991749408, 560813.8524032757],
#      [167232.171604658, 560792.31215418],
#      [167231.51453784498, 560792.150136266],
#      [167199.97451578872, 560792.150136266],
#      [167197.39395552597, 560796.5944344884],
#      [167192.16612500112, 560802.8678311276],
#      [167188.92487008058, 560806.109086046],
#      [167180.9785676768, 560811.5460297927],
#      [167175.0188408795, 560814.264501674],
#      [167169.79101035465, 560816.3556338736],
#      [167164.87684966277, 560817.4011999835],
#      [167159.75357574006, 560817.9239830318],
#      [167155.00338564828, 560818.0465508976],
#      [167151.3814842838, 560817.3351059853],
#      [167145.33964067846, 560845.7177201264],
#      [167149.42834647148, 560847.5534655827],
#      [167155.95522161067, 560852.0406922395],
#      [167162.07416705298, 560857.343778297],
#      [167166.96932340015, 560863.8706534251],
#      [167172.95229228275, 560874.204872396],
#      [167175.3998704597, 560881.1396772255],
#      [167176.75963610783, 560890.3860836765],
#      [167176.48768297955, 560895.825146287],
#      [167175.10128924533, 560901.5093605908],
#      [167203.79187169985, 560906.0340402627],
#      [167207.0824101844, 560898.1367479042],
#      [167207.30536615534, 560897.7709636857],
#      [167215.32398132954, 560887.2224561252],
#      [167222.25470292947, 560881.72567692],
#      [167226.31753973538, 560878.8577921238],
#      [167231.81431893609, 560876.2288977216],
#      [167234.68220373895, 560875.2729361169],
#      [167240.89595414372, 560873.361012921],
#      [167252.74010115582, 560872.8887947166],
#      [167256.4463261224, 560872.8885661135],
#      [167263.41823240294, 560874.3272134445]],
#     [[167220.9560545392, 560861.2992277081],
#      [167252.5820532714, 560868.6215018841],
#      [167240.17898293966, 560869.0591857143],
#      [167233.96523253713, 560870.971108917],
#      [167225.36157813072, 560874.3169745189],
#      [167219.8647989278, 560876.7068785205],
#      [167211.73912532264, 560882.2036577213],
#      [167205.38350820102, 560889.0889096056],
#      [167210.7578626337, 560868.7517525653],
#      [167212.06532313555, 560863.7834026605],
#      [167212.457561285, 560862.6066882123],
#      [167213.11129153924, 560861.5607198152],
#      [167214.2880059898, 560860.9069895587],
#      [167215.59546648496, 560860.5147514071],
#      [167220.9560545392, 560861.2992277081]],
#     [[167181.4619720925, 560851.8142010425],
#      [167189.57700251942, 560853.9774489023],
#      [167187.37853331747, 560863.6168907948],
#      [167181.62648472408, 560888.8374115597],
#      [167180.83893306568, 560888.6183883159],
#      [167179.3431908467, 560880.4597943936],
#      [167176.35170641096, 560871.3493645155],
#      [167174.17608136233, 560866.4542081617],
#      [167171.0486203602, 560861.8310049406],
#      [167169.6888547076, 560860.063309591],
#      [167165.47358118117, 560854.4882704099],
#      [167159.35463573664, 560849.1851843613],
#      [167151.19604181653, 560843.7461217464],
#      [167181.4619720925, 560851.8142010425]],
#     [[167232.2922997351, 560821.0221152807],
#      [167235.39917493856, 560827.7138464844],
#      [167237.311098139, 560831.0597120863],
#      [167249.5243168551, 560844.776096181],
#      [167225.27067419636, 560839.333891295],
#      [167219.12560984326, 560838.1571768422],
#      [167218.21038749086, 560837.6341926459],
#      [167217.5566572433, 560836.4574781931],
#      [167217.42591118976, 560835.6730018898],
#      [167219.2563558879, 560829.004953336],
#      [167225.97433590805, 560802.4755121925],
#      [167232.2922997351, 560821.0221152807]],
#     [[167196.7971003383, 560823.754737756],
#      [167194.6760984755, 560830.9661440876],
#      [167186.49145251626, 560829.2782599016],
#      [167162.25467509497, 560824.2800139759],
#      [167162.77406225278, 560823.1213810855],
#      [167166.95793585424, 560822.075412684],
#      [167171.01106340438, 560821.0294442825],
#      [167176.11015936045, 560819.4604916803],
#      [167180.29403296413, 560817.7607930313],
#      [167186.3083512704, 560814.6228878313],
#      [167189.8384946198, 560811.8772207807],
#      [167193.49938402273, 560809.131553728],
#      [167197.6832576264, 560804.2939498723],
#      [167204.48205223153, 560797.6259013207],
#      [167196.7971003383, 560823.754737756]]]}},
#  {'type': 'Feature',
#   'properties': {'ANN_CD': 30, 'ANN_NM': '도로'},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[167355.3500000034, 560869.4767829783],
#      [167311.39852617204, 560858.6598714562],
#      [167268.53786615707, 560849.0424916383],
#      [167263.41823240294, 560874.3272134445],
#      [167266.74986363348, 560875.0146929026],
#      [167315.97787617304, 560886.7901643435],
#      [167355.3500000034, 560896.7748216459],
#      [167355.3500000034, 560869.4767829783]]]}},
#  {'type': 'Feature',
#   'properties': {'ANN_CD': 30, 'ANN_NM': '도로'},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[167232.2098897133, 560792.150136266],
#      [167231.51453784498, 560792.150136266],
#      [167232.171604658, 560792.31215418],
#      [167232.2098897133, 560792.150136266]]]}},
#  {'type': 'Feature',
#   'properties': {'ANN_CD': 30, 'ANN_NM': '도로'},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[167154.04332450373, 561053.2701362699],
#      [167163.74816858693, 561053.2701362699],
#      [167168.69251731853, 561033.4927413455],
#      [167159.05193732836, 561031.2834417624],
#      [167156.94402816583, 561040.6170668615],
#      [167154.04332450373, 561053.2701362699]]]}},
#  {'type': 'Feature',
#   'properties': {'ANN_CD': 30, 'ANN_NM': '도로'},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[167139.43107513105, 561053.2701362699],
#      [167149.986078034, 561053.2701362699],
#      [167151.79541338675, 561044.9933894222],
#      [167155.2077740636, 561030.4024876856],
#      [167145.10299562346, 561028.0868092882],
#      [167139.43107513105, 561053.2701362699]]]}},
#  {'type': 'Feature',
#   'properties': {'ANN_CD': 30, 'ANN_NM': '도로'},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[167151.3814842838, 560817.3351059853],
#      [167147.38869798701, 560816.550808672],
#      [167116.82791963933, 560809.0584888234],
#      [167094.22999999954, 560803.5183536848],
#      [167094.22999999954, 560832.890235196],
#      [167111.21893160755, 560836.9472934878],
#      [167132.70322893435, 560842.1144029722],
#      [167142.76549476813, 560844.5619811491],
#      [167145.33964067846, 560845.7177201264],
#      [167151.3814842838, 560817.3351059853]]]}},
#  {'type': 'Feature',
#   'properties': {'ANN_CD': 30, 'ANN_NM': '도로'},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[167203.79187169985, 560906.0340402627],
#      [167175.10128924533, 560901.5093605908],
#      [167173.76815166767, 560906.9752246473],
#      [167168.73701875634, 560929.5473344962],
#      [167169.0089718802, 560942.0571785179],
#      [167166.34060284647, 560952.93948977],
#      [167148.2626734643, 561022.757699786],
#      [167156.94295102335, 561024.8278915096],
#      [167172.44046181696, 560965.0761798222],
#      [167181.01205046664, 560930.107994316],
#      [167181.79128580328, 560928.4521192313],
#      [167182.86273438114, 560928.062501574],
#      [167183.54456529737, 560928.3547148198],
#      [167184.1289917954, 560929.2313545701],
#      [167184.22639621136, 560930.2053987321],
#      [167175.84961639586, 560965.9528195747],
#      [167169.61573374274, 560990.2065192643],
#      [167160.5599219824, 561025.690516377],
#      [167170.70604669454, 561028.1103034427],
#      [167183.0570585789, 560978.4933074497],
#      [167184.76064642306, 560971.6789560687],
#      [167191.042626593, 560958.5826245089],
#      [167198.51588657184, 560928.3235454077],
#      [167197.97198030635, 560926.8278031909],
#      [167197.70002717583, 560925.6040141025],
#      [167197.70002717583, 560924.2442484454],
#      [167198.10795687052, 560923.2924124898],
#      [167198.92381626653, 560921.6606937088],
#      [167198.9238162643, 560920.300928054],
#      [167198.78783970015, 560918.5332327023],
#      [167198.9238162643, 560917.4454201846],
#      [167200.0116287886, 560916.2216310961],
#      [167200.69151160936, 560915.269795136],
#      [167203.68299604955, 560906.2953418199],
#      [167203.79187169985, 560906.0340402627]]]}},
#  {'type': 'Feature',
#   'properties': {'ANN_CD': 100, 'ANN_NM': '비대상지'},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[167199.97451578872, 560792.150136266],
#      [167175.20775271166, 560792.150136266],
#      [167174.05255905495, 560796.6912423607],
#      [167153.8840144171, 560810.1369387897],
#      [167149.21105429117, 560809.1521290217],
#      [167146.14136993943, 560808.3792041454],
#      [167149.44776496303, 560795.4685188083],
#      [167144.3805187422, 560794.1042602079],
#      [167144.3805187422, 560792.150136266],
#      [167095.6468231578, 560792.150136266],
#      [167095.02321734745, 560795.50801371],
#      [167094.22999999954, 560795.3082871719],
#      [167094.22999999954, 560803.5183536848],
#      [167116.82791963933, 560809.0584888234],
#      [167147.38869798701, 560816.550808672],
#      [167151.3814842838, 560817.3351059853],
#      [167155.00338564828, 560818.0465508976],
#      [167159.75357574006, 560817.9239830318],
#      [167164.87684966277, 560817.4011999835],
#      [167169.79101035465, 560816.3556338736],
#      [167175.0188408795, 560814.264501674],
#      [167180.9785676768, 560811.5460297927],
#      [167188.92487008058, 560806.109086046],
#      [167192.16612500112, 560802.8678311276],
#      [167197.39395552597, 560796.5944344884],
#      [167199.97451578872, 560792.150136266]]]}},
#  {'type': 'Feature',
#   'properties': {'ANN_CD': 100, 'ANN_NM': '비대상지'},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[167196.7971003383, 560823.754737756],
#      [167204.48205223153, 560797.6259013207],
#      [167197.6832576264, 560804.2939498723],
#      [167193.49938402273, 560809.131553728],
#      [167189.8384946198, 560811.8772207807],
#      [167186.3083512704, 560814.6228878313],
#      [167180.29403296413, 560817.7607930313],
#      [167176.11015936045, 560819.4604916803],
#      [167171.01106340438, 560821.0294442825],
#      [167166.95793585424, 560822.075412684],
#      [167162.77406225278, 560823.1213810855],
#      [167162.25467509497, 560824.2800139759],
#      [167186.49145251626, 560829.2782599016],
#      [167194.6760984755, 560830.9661440876],
#      [167196.7971003383, 560823.754737756]]]}},
#  {'type': 'Feature',
#   'properties': {'ANN_CD': 100, 'ANN_NM': '비대상지'},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[167232.2922997351, 560821.0221152807],
#      [167225.97433590805, 560802.4755121925],
#      [167219.2563558879, 560829.004953336],
#      [167217.42591118976, 560835.6730018898],
#      [167217.5566572433, 560836.4574781931],
#      [167218.21038749086, 560837.6341926459],
#      [167219.12560984326, 560838.1571768422],
#      [167225.27067419636, 560839.333891295],
#      [167249.5243168551, 560844.776096181],
#      [167237.311098139, 560831.0597120863],
#      [167235.39917493856, 560827.7138464844],
#      [167232.2922997351, 560821.0221152807]]]}},
#  {'type': 'Feature',
#   'properties': {'ANN_CD': 100, 'ANN_NM': '비대상지'},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[167232.2098897133, 560792.150136266],
#      [167232.171604658, 560792.31215418],
#      [167235.3991749408, 560813.8524032757],
#      [167236.35513654322, 560818.8712016819],
#      [167238.98403094328, 560824.6069712832],
#      [167243.76383894213, 560832.7326448906],
#      [167246.87071415008, 560836.0785104969],
#      [167252.12850295237, 560840.1413472962],
#      [167268.53786615707, 560849.0424916383],
#      [167311.39852617204, 560858.6598714562],
#      [167355.3500000034, 560869.4767829783],
#      [167355.3500000034, 560792.150136266],
#      [167232.2098897133, 560792.150136266]],
#     [[167322.8489230154, 560836.7208120805],
#      [167316.80407527077, 560838.2728675863],
#      [167309.1254848922, 560831.6562099203],
#      [167310.10573047213, 560830.3492158123],
#      [167308.71704923152, 560829.1239088346],
#      [167304.79606691631, 560832.9632040261],
#      [167298.83290630204, 560827.0000434185],
#      [167302.75388862166, 560823.0790611011],
#      [167302.2637658284, 560822.425564036],
#      [167301.2018331159, 560823.4058096203],
#      [167294.91192398462, 560817.5243361408],
#      [167296.46397948152, 560815.8089063744],
#      [167294.5851754565, 560814.0934766122],
#      [167291.8078129775, 560816.7074648172],
#      [167291.56275157974, 560819.4031401725],
#      [167285.35452957882, 560826.1014849667],
#      [167278.57449764758, 560827.4901662095],
#      [167272.0508035167, 560821.4628401108],
#      [167271.75339560368, 560818.6519574972],
#      [167277.43096556852, 560813.4547986492],
#      [167289.84732181768, 560799.6348542981],
#      [167298.3427835132, 560798.4095473225],
#      [167329.3022064185, 560828.9605345783],
#      [167322.8489230154, 560836.7208120805]]]}},
#  {'type': 'Feature',
#   'properties': {'ANN_CD': 100, 'ANN_NM': '비대상지'},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[167181.4619720925, 560851.8142010425],
#      [167151.19604181653, 560843.7461217464],
#      [167159.35463573664, 560849.1851843613],
#      [167165.47358118117, 560854.4882704099],
#      [167169.6888547076, 560860.063309591],
#      [167171.0486203602, 560861.8310049406],
#      [167174.17608136233, 560866.4542081617],
#      [167176.35170641096, 560871.3493645155],
#      [167179.3431908467, 560880.4597943936],
#      [167180.83893306568, 560888.6183883159],
#      [167181.62648472408, 560888.8374115597],
#      [167187.37853331747, 560863.6168907948],
#      [167189.57700251942, 560853.9774489023],
#      [167181.4619720925, 560851.8142010425]]]}},
#  {'type': 'Feature',
#   'properties': {'ANN_CD': 100, 'ANN_NM': '비대상지'},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[167220.9560545392, 560861.2992277081],
#      [167215.59546648496, 560860.5147514071],
#      [167214.2880059898, 560860.9069895587],
#      [167213.11129153924, 560861.5607198152],
#      [167212.457561285, 560862.6066882123],
#      [167212.06532313555, 560863.7834026605],
#      [167210.7578626337, 560868.7517525653],
#      [167205.38350820102, 560889.0889096056],
#      [167211.73912532264, 560882.2036577213],
#      [167219.8647989278, 560876.7068785205],
#      [167225.36157813072, 560874.3169745189],
#      [167233.96523253713, 560870.971108917],
#      [167240.17898293966, 560869.0591857143],
#      [167252.5820532714, 560868.6215018841],
#      [167220.9560545392, 560861.2992277081]]]}},
#  {'type': 'Feature',
#   'properties': {'ANN_CD': 100, 'ANN_NM': '비대상지'},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[167355.3500000034, 561020.6249100823],
#      [167355.3500000034, 561019.6463796619],
#      [167354.76795464545, 561019.869103472],
#      [167355.3500000034, 561020.6249100823]]]}},
#  {'type': 'Feature',
#   'properties': {'ANN_CD': 100, 'ANN_NM': '비대상지'},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[167355.3500000034, 561053.2701362699],
#      [167355.3500000034, 561051.5041432474],
#      [167353.29703478861, 561048.7912963531],
#      [167351.6600558057, 561049.814408213],
#      [167348.48840903738, 561045.8242719576],
#      [167350.33001038874, 561044.3919153477],
#      [167348.79534259223, 561042.7549363713],
#      [167352.47854529938, 561040.0948455308],
#      [167352.27392292206, 561039.0717336687],
#      [167349.920765643, 561039.5832896008],
#      [167345.7260070126, 561034.3654191105],
#      [167344.9075175189, 561034.7746638496],
#      [167345.7260070126, 561036.6162652076],
#      [167343.34707305866, 561037.7990700483],
#      [167339.0710262581, 561040.8601027783],
#      [167340.6351471989, 561043.0090667136],
#      [167336.7549615332, 561046.1600408434],
#      [167329.45852841862, 561052.1675654965],
#      [167322.6036789454, 561044.903471282],
#      [167330.11112963877, 561038.3522328055],
#      [167333.90806349248, 561035.0740698952],
#      [167331.60706332483, 561028.6359926836],
#      [167330.3793290854, 561029.1475486158],
#      [167328.23079418365, 561023.1111886295],
#      [167330.68626264913, 561018.2002516985],
#      [167333.76398862022, 561016.644131006],
#      [167339.84911125764, 561014.5149691848],
#      [167340.93708294808, 561017.2949531376],
#      [167355.3500000034, 561012.3065894635],
#      [167355.3500000034, 560896.7748216459],
#      [167315.97787617304, 560886.7901643435],
#      [167266.74986363348, 560875.0146929026],
#      [167263.41823240294, 560874.3272134445],
#      [167256.4463261224, 560872.8885661135],
#      [167252.74010115582, 560872.8887947166],
#      [167240.89595414372, 560873.361012921],
#      [167234.68220373895, 560875.2729361169],
#      [167231.81431893609, 560876.2288977216],
#      [167226.31753973538, 560878.8577921238],
#      [167222.25470292947, 560881.72567692],
#      [167215.32398132954, 560887.2224561252],
#      [167207.30536615534, 560897.7709636857],
#      [167207.0824101844, 560898.1367479042],
#      [167203.79187169985, 560906.0340402627],
#      [167203.68299604955, 560906.2953418199],
#      [167200.69151160936, 560915.269795136],
#      [167200.0116287886, 560916.2216310961],
#      [167198.9238162643, 560917.4454201846],
#      [167198.78783970015, 560918.5332327023],
#      [167198.9238162643, 560920.300928054],
#      [167198.92381626653, 560921.6606937088],
#      [167198.10795687052, 560923.2924124898],
#      [167197.70002717583, 560924.2442484454],
#      [167197.70002717583, 560925.6040141025],
#      [167197.97198030635, 560926.8278031909],
#      [167198.51588657184, 560928.3235454077],
#      [167191.042626593, 560958.5826245089],
#      [167184.76064642306, 560971.6789560687],
#      [167183.0570585789, 560978.4933074497],
#      [167170.70604669454, 561028.1103034427],
#      [167160.5599219824, 561025.690516377],
#      [167169.61573374274, 560990.2065192643],
#      [167175.84961639586, 560965.9528195747],
#      [167184.22639621136, 560930.2053987321],
#      [167184.1289917954, 560929.2313545701],
#      [167183.54456529737, 560928.3547148198],
#      [167182.86273438114, 560928.062501574],
#      [167181.79128580328, 560928.4521192313],
#      [167181.01205046664, 560930.107994316],
#      [167172.44046181696, 560965.0761798222],
#      [167156.94295102335, 561024.8278915096],
#      [167148.2626734643, 561022.757699786],
#      [167166.34060284647, 560952.93948977],
#      [167169.0089718802, 560942.0571785179],
#      [167168.73701875634, 560929.5473344962],
#      [167173.76815166767, 560906.9752246473],
#      [167175.10128924533, 560901.5093605908],
#      [167176.48768297955, 560895.825146287],
#      [167176.75963610783, 560890.3860836765],
#      [167175.3998704597, 560881.1396772255],
#      [167172.95229228275, 560874.204872396],
#      [167166.96932340015, 560863.8706534251],
#      [167162.07416705298, 560857.343778297],
#      [167155.95522161067, 560852.0406922395],
#      [167149.42834647148, 560847.5534655827],
#      [167145.33964067846, 560845.7177201264],
#      [167142.76549476813, 560844.5619811491],
#      [167132.70322893435, 560842.1144029722],
#      [167111.21893160755, 560836.9472934878],
#      [167094.22999999954, 560832.890235196],
#      [167094.22999999954, 560956.6269933472],
#      [167102.56995688187, 560951.4585693647],
#      [167104.65630425475, 560948.9858613648],
#      [167102.78113830625, 560947.4650850107],
#      [167115.78402664047, 560931.4960474982],
#      [167127.61010391888, 560941.1291482951],
#      [167124.39602387964, 560945.1307795263],
#      [167132.54240729476, 560951.2607314016],
#      [167131.84997444483, 560954.4261387099],
#      [167126.1126737088, 560962.1418190153],
#      [167124.03537515897, 560961.6472241218],
#      [167124.6288890351, 560964.515874491],
#      [167138.97214088298, 560980.540748969],
#      [167131.65213649056, 560985.3877789052],
#      [167128.18997224973, 560981.0353438625],
#      [167125.61807881534, 560982.5191285361],
#      [167122.05012786016, 560981.664090976],
#      [167119.2089874192, 560978.2019899201],
#      [167117.97512162945, 560979.2890673159],
#      [167113.28496253848, 560973.4710114154],
#      [167105.438607251, 560977.3753416651],
#      [167104.94401235756, 560975.8915569914],
#      [167101.58076709943, 560977.4742606434],
#      [167094.22999999954, 560974.344726133],
#      [167094.22999999954, 561053.2701362699],
#      [167139.43107513105, 561053.2701362699],
#      [167145.10299562346, 561028.0868092882],
#      [167155.2077740636, 561030.4024876856],
#      [167151.79541338675, 561044.9933894222],
#      [167149.986078034, 561053.2701362699],
#      [167154.04332450373, 561053.2701362699],
#      [167156.94402816583, 561040.6170668615],
#      [167159.05193732836, 561031.2834417624],
#      [167168.69251731853, 561033.4927413455],
#      [167163.74816858693, 561053.2701362699],
#      [167355.3500000034, 561053.2701362699]],
#     [[167139.667088201, 560910.4451189712],
#      [167136.87514719143, 560906.9830137955],
#      [167135.54008106675, 560908.0700849127],
#      [167130.8500214682, 560902.252029814],
#      [167132.18906786534, 560901.2031269942],
#      [167130.61707684185, 560899.377035644],
#      [167129.88396855313, 560900.0550365637],
#      [167122.45721221785, 560903.899177033],
#      [167121.49486722695, 560902.2494427552],
#      [167117.37053153935, 560904.4490884523],
#      [167110.10608116153, 560901.5020902543],
#      [167106.35507616375, 560894.6069910957],
#      [167107.66205699072, 560893.9060407782],
#      [167106.9911413878, 560892.7792325799],
#      [167111.16711855764, 560890.4528607074],
#      [167111.02207801936, 560890.1880939584],
#      [167116.35098333095, 560887.2200382691],
#      [167116.6459748314, 560887.8450982528],
#      [167121.83601482926, 560884.9551302389],
#      [167125.67502391397, 560880.3230123289],
#      [167125.07212533953, 560879.8731065515],
#      [167128.96613178935, 560875.1171041923],
#      [167129.10000803004, 560875.3060174391],
#      [167132.1562470495, 560871.6141280464],
#      [167133.10199448065, 560872.4221206134],
#      [167134.05695088927, 560871.3082479902],
#      [167143.07889066264, 560873.6540486393],
#      [167149.5403499126, 560879.1531629006],
#      [167141.15420067863, 560889.6014799795],
#      [167155.4518977344, 560906.7862120101],
#      [167147.8906156393, 560912.9727155493],
#      [167139.667088201, 560910.4451189712]],
#     [[167235.44832668253, 561022.3768373806],
#      [167232.52434719505, 561022.288231944],
#      [167229.1573405087, 561017.7693545566],
#      [167227.82825892328, 561018.744014382],
#      [167224.72706855802, 561014.9339805035],
#      [167226.2333610212, 561013.9593206714],
#      [167224.99288487688, 561012.3644227649],
#      [167229.24594594535, 561008.7315997664],
#      [167228.18268068103, 561007.4025181831],
#      [167226.76499365893, 561007.9341508164],
#      [167224.1479811599, 561004.2108538988],
#      [167218.6342404408, 561008.959122073],
#      [167220.34899553633, 561010.861067898],
#      [167216.34400334957, 561014.3870425394],
#      [167215.95596410587, 561013.9490865096],
#      [167212.87296543794, 561016.5209695457],
#      [167205.5882937199, 561022.3768373806],
#      [167198.4998585917, 561013.9593206714],
#      [167210.28438198945, 561004.5671441323],
#      [167207.892035133, 560997.6559198863],
#      [167206.82876986422, 560998.0103416418],
#      [167204.17060669116, 560990.8333010792],
#      [167205.1452665255, 560988.6181651028],
#      [167213.33808564203, 560984.8221396599],
#      [167219.2311458744, 560982.8539786482],
#      [167220.0460842025, 560985.2279632568],
#      [167231.37610642423, 560981.2830740884],
#      [167231.6539914273, 560982.0771029466],
#      [167237.0860169526, 560979.6189777546],
#      [167239.56011861726, 560986.0289688446],
#      [167234.6110418231, 560987.9350046684],
#      [167235.0362410257, 560988.9580333263],
#      [167238.44804530405, 560992.952864788],
#      [167238.82797794006, 560992.803136308],
#      [167242.28295721186, 560997.0340480445],
#      [167242.0520826846, 560997.2390904585],
#      [167245.7649920909, 561001.3280599248],
#      [167246.52912252743, 561000.6071426548],
#      [167252.3109792602, 561007.5150700741],
#      [167251.4550368271, 561008.3822499528],
#      [167252.1220455698, 561009.1789533957],
#      [167250.6300716194, 561010.4600907428],
#      [167251.12695805245, 561011.11497087],
#      [167247.45106380593, 561014.375072175],
#      [167240.67604758314, 561019.718674212],
#      [167239.61278231879, 561018.5668034998],
#      [167235.44832668253, 561022.3768373806]],
#     [[167291.54433339156, 560953.183123925],
#      [167303.61639794608, 560941.516843051],
#      [167300.37012848974, 560935.7344255822],
#      [167298.74699375936, 560936.2416551859],
#      [167296.00795390236, 560930.662129542],
#      [167296.71807533968, 560927.3144141666],
#      [167301.02000222076, 560925.593976296],
#      [167306.99211027566, 560922.8152484024],
#      [167308.09408295064, 560925.4800994821],
#      [167324.44798793978, 560918.4080040146],
#      [167327.33608573672, 560924.7371393994],
#      [167322.57099769614, 560926.8760058968],
#      [167327.0509947526, 560931.9380082816],
#      [167327.3140790117, 560931.4959862899],
#      [167330.94207278514, 560934.9630827528],
#      [167330.52697838063, 560935.366013729],
#      [167334.48300476928, 560939.4151311666],
#      [167335.46202234458, 560938.4978563247],
#      [167341.71009084652, 560945.1720854511],
#      [167340.7491312696, 560946.1359730588],
#      [167341.44411208347, 560946.8051138818],
#      [167340.02024448663, 560948.2430364601],
#      [167340.60909014937, 560948.8178782534],
#      [167337.24800457526, 560952.1381454841],
#      [167336.49101220875, 560951.2539650323],
#      [167331.97995581533, 560955.4680212989],
#      [167331.45824807286, 560954.8750972905],
#      [167330.47312347498, 560955.7490913301],
#      [167327.55763520833, 560958.661203639],
#      [167322.99256878518, 560953.6903535288],
#      [167321.6737718162, 560954.7048127365],
#      [167318.32605643198, 560951.7628810349],
#      [167319.74629931996, 560949.9368544642],
#      [167317.81882682818, 560948.4151656551],
#      [167321.87666365417, 560944.6616665905],
#      [167320.86220445542, 560943.6472073828],
#      [167319.13762379717, 560944.6616665905],
#      [167316.68074947194, 560941.0159820998],
#      [167315.30307985898, 560941.6179725076],
#      [167313.41506898188, 560943.3300525164],
#      [167311.4541040348, 560944.9911256599],
#      [167311.89300661522, 560945.5640677403],
#      [167308.45498173495, 560949.0179722926],
#      [167310.13498484032, 560950.9340709016],
#      [167306.45287062673, 560954.6699747348],
#      [167306.06101160037, 560954.2950871632],
#      [167303.08405468304, 560957.2039552632],
#      [167299.1527774353, 560960.5886761287],
#      [167291.54433339156, 560953.183123925]],
#     [[167252.04824081488, 560916.9412459965],
#      [167262.10399252176, 560928.4099989003],
#      [167262.83914319478, 560927.7550840958],
#      [167269.6060058754, 560935.9970003574],
#      [167268.66724444617, 560936.9560715902],
#      [167269.35596500337, 560937.9021436654],
#      [167267.87812527452, 560939.1590478806],
#      [167268.29999997563, 560939.8520081994],
#      [167264.7811187794, 560942.5980306603],
#      [167264.05198388055, 560941.598990874],
#      [167258.8738596837, 560945.4591001828],
#      [167258.49023651986, 560945.1001285907],
#      [167257.5760913255, 560945.6891326135],
#      [167250.92354804897, 560950.301159262],
#      [167246.22596792597, 560944.916128395],
#      [167244.85106642707, 560945.9473045209],
#      [167241.87211318495, 560942.3954756503],
#      [167243.81989030787, 560940.5622736474],
#      [167242.33041368236, 560938.9582219041],
#      [167247.37171917842, 560935.0626676605],
#      [167246.22596792597, 560933.8023412793],
#      [167243.7053151835, 560935.5209681579],
#      [167241.54596520928, 560932.297961377],
#      [167236.10803192388, 560936.9561020677],
#      [167237.6860067826, 560939.1609599106],
#      [167233.55495737024, 560942.6859964053],
#      [167233.26401963894, 560942.5081494094],
#      [167230.33012391775, 560945.0739915817],
#      [167222.6234922111, 560949.4991333914],
#      [167214.946958846, 560941.7080248976],
#      [167227.66479770272, 560931.396263659],
#      [167222.6234922111, 560919.7096009281],
#      [167224.57126933403, 560915.5848964335],
#      [167230.62204339448, 560913.2440587617],
#      [167236.64699565776, 560911.251958025],
#      [167237.4061213927, 560913.7559913207],
#      [167248.6602416809, 560909.7280008227],
#      [167248.91824949626, 560910.3850751801],
#      [167254.68312194844, 560908.2559734501],
#      [167256.9509757456, 560914.6271180671],
#      [167252.15199401972, 560916.1091373109],
#      [167252.04824081488, 560916.9412459965]]]}}]

# %% [markdown]
# From the label_dict, we can see that the 10th(index = 9) feature corresponds to a road and the 3rd(index = 2) feature corresponds to a building.
#
# Before plotting, we extract information from the META file:

# %%
meta_coord = meta_dict[0]['coordinates']
mc_split = meta_coord.split(', ')
org_x = float(mc_split[0])
org_y = float(mc_split[1])
img_res = meta_dict[0]['img_resolution']

# %% [markdown]
# **Example of a Road**

# %%
label_dict['features'][10]
# Out:
# {'type': 'Feature',
#  'properties': {'ANN_CD': 30, 'ANN_NM': '도로'},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[167355.3500000034, 560869.4767829783],
#     [167311.39852617204, 560858.6598714562],
#     [167268.53786615707, 560849.0424916383],
#     [167263.41823240294, 560874.3272134445],
#     [167266.74986363348, 560875.0146929026],
#     [167315.97787617304, 560886.7901643435],
#     [167355.3500000034, 560896.7748216459],
#     [167355.3500000034, 560869.4767829783]]]}}

# %%
feature = label_dict['features'][10]
coords = feature['geometry']['coordinates'][0]

transformed_coords = []
for point in coords:
    tpoint = (max(0,point[0]-org_x), max(0,org_y-point[1]))
    transformed_coords.append(tpoint)
xs = [x[0]*(1/img_res) for x in transformed_coords]
ys = [x[1]*(1/img_res) for x in transformed_coords]

# %%
plt.figure()
plt.imshow(im)
plt.scatter(xs,ys)

# %% [markdown]
# We can see that this particular feature corresponds to the road on the right.

# %% [markdown]
# **Example of a Building**

# %%
label_dict['features'][2]
# Out:
# {'type': 'Feature',
#  'properties': {'ANN_CD': 10, 'ANN_NM': '건물'},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[167322.8489230154, 560836.7208120805],
#     [167329.3022064185, 560828.9605345783],
#     [167298.3427835132, 560798.4095473225],
#     [167289.84732181768, 560799.6348542981],
#     [167277.43096556852, 560813.4547986492],
#     [167271.75339560368, 560818.6519574972],
#     [167272.0508035167, 560821.4628401108],
#     [167278.57449764758, 560827.4901662095],
#     [167285.35452957882, 560826.1014849667],
#     [167291.56275157974, 560819.4031401725],
#     [167291.8078129775, 560816.7074648172],
#     [167294.5851754565, 560814.0934766122],
#     [167296.46397948152, 560815.8089063744],
#     [167294.91192398462, 560817.5243361408],
#     [167301.2018331159, 560823.4058096203],
#     [167302.2637658284, 560822.425564036],
#     [167302.75388862166, 560823.0790611011],
#     [167298.83290630204, 560827.0000434185],
#     [167304.79606691631, 560832.9632040261],
#     [167308.71704923152, 560829.1239088346],
#     [167310.10573047213, 560830.3492158123],
#     [167309.1254848922, 560831.6562099203],
#     [167316.80407527077, 560838.2728675863],
#     [167322.8489230154, 560836.7208120805]]]}}

# %%
feature = label_dict['features'][2]
coords = feature['geometry']['coordinates'][0]

transformed_coords = []
for point in coords:
    tpoint = (max(0,point[0]-org_x), max(0,org_y-point[1]))
    transformed_coords.append(tpoint)
xs = [x[0]*(1/img_res) for x in transformed_coords]
ys = [x[1]*(1/img_res) for x in transformed_coords]

plt.figure()
plt.imshow(im)
plt.scatter(xs,ys)

# %% [markdown]
# Because there was no explanation of the information contained within the json files, it took a lot of trial and error to figure out how to properly draw the polygons onto the image.
# * 'coordinates' of a feature in the label files are polygon coordinates for the given feature.
#     * The corodinates are stored as a list of lists.
#     * Each inner list has a length of 2, with the first element corresponding to the x-coordinate and the second element corresponding to the y-coordinate.
# * HOWEVER, these coordinates have to be transformed before plotting on to the image.
# * 'coordinates' in the META files refer to the coordinates of the origin of the corresponding 'tiff' file.
# * To properly plot the polygon coordinates of a given feature, the coordinate value of the origin must be subtracted from the polygon of the coordinate.
# * Furthermore, to properly scale the coordinates of the polygons, the difference in coordinate values must be divided by the 'img_resolution' provided in the META file.

# %% [markdown]
# ## Process the raw data

# %% [markdown]
# We now process the raw data in order to make the dataset used for our image segmentation competition. We begin by making image masks.

# %% [markdown]
# ### Making image masks
# Having looked through many examples within the dataset, we concluded that the labelling quality of the 'building' features were best. Therefore, we decided to make the task be determining whether or not each pixel of the image corresponds to a building.

# %% [markdown]
# We first extract only the images that contain buildings:

# %%
contains_buildings = []
for lbl in label_jsons:
    # load label json file
    lbl_path = os.path.join(labeljsons_path,lbl)
    label = json.load(open(lbl_path))
    # loop through featrues
    for feat in label['features']:
        if feat['properties']['ANN_CD']==10:
            img_name = lbl.split('_FGT.json')[0]
            contains_buildings.append(img_name)
            break

len(contains_buildings)
# Out:
# 10533

# %% [markdown]
# We see that 10533 of the total 13520 images contain buildings. We use only these images.

# %% [markdown]
# #### Example Image mask

# %%
# Function to transform polygon coordinates
def coord_to_points(coords, org_x, org_y, resolution):
    new_coord = []
    for point in coords:
        npoint = (max(0,point[0]-org_x), max(0,org_y-point[1]))
        new_coord.append(npoint)
    xs = [int(np.round(x[0]/resolution)) for x in new_coord]
    ys = [int(np.round(x[1]/resolution)) for x in new_coord]
    return xs,ys

# %%
rawtiffs_path = '/workspace/Competition/map_segmentation/data/RAW/train/raw_tiffs'
labeljsons_path = '/workspace/Competition/map_segmentation/data/RAW/train/label_json'
metafiles_path = '/workspace/Competition/map_segmentation/data/RAW/train/meta'

# %%
# File names
fid = contains_buildings[0]
imfile = fid+'.tif'
metafile = fid + '_META.json'
labelfile = fid + '_FGT.json'

# File paths
impath = os.path.join(rawtiffs_path, imfile)
metapath = os.path.join(metafiles_path, metafile)
labelpath = os.path.join(labeljsons_path, labelfile)

# Load files
im = tiff.imread(impath)
label_dict = json.load(open(labelpath))
meta_dict = json.load(open(metapath))

# Load coordinates for buildings
building_coordinates = []
for feat in label_dict['features']:
    if feat['properties']['ANN_CD']==10:
        coords = feat['geometry']['coordinates'][0]
        building_coordinates.append(coords)

# Load META info
meta_coord = meta_dict[0]['coordinates']
mc_split = meta_coord.split(', ')
org_x = float(mc_split[0])
org_y = float(mc_split[1])
img_res = meta_dict[0]['img_resolution']

# Make and combine masks
allmasks = []
for sub_coord in building_coordinates:
    xs,ys = coord_to_points(sub_coord, org_x, org_y, img_res)
    points = np.array(list(zip(xs,ys)))
    maskim = np.zeros((512,512),dtype=np.int32)
    maskim = cv2.fillPoly(maskim, pts=[points], color=(255,255,255))
    allmasks.append(maskim)
fin_mask = np.zeros((512,512), dtype=np.int32)
for submask in allmasks:
    fin_mask = fin_mask + submask

plt.figure()
plt.subplot(1,2,1)
plt.imshow(im)
plt.subplot(1,2,2)
plt.imshow(fin_mask)

# %% [markdown]
# We have succesfully made a mask for this first image.
# The following script is used to make masks for all images containing buildings. It also converts all the '.tif' images.
# ```
# make_masks.py
# ```

# %% [markdown]
# The script takes 2 arguments:
# * *input_dir*: Path to directory containing the 'raw_tiffs', 'label_json', and 'meta_fixed' folders.
# * *output_dir*: Path to directory that will contain the processed images.

# %% [markdown]
# ## Splitting the data into train and test

# %% [markdown]
# Having run the scripts above, we first check to see if the names of the images match the names of the masks:

# %%
images_path =  '/workspace/Competition/map_segmentation/data/processed/input_images'
masks_path = '/workspace/Competition/map_segmentation/data/processed/masks'

images = os.listdir(images_path)
masks = os.listdir(masks_path)

images.sort()
masks.sort()

images==masks
# Out:
# True

# %% [markdown]
# Process of splitting the data:
# * Randomly select 20% of the data to use as test data.
# * Encode file name to prevent any information to remain in file names.
# * Save original file name and encoded file name as csv.
# * Save a data frame with the train image and mask names.
#
# This is done with the script *split_data.py*. It takes two arguments:
# * *input_dir*: Path to directory containing the folders of the raw image files and the mask files.
# * *output_dir*: Path to directory that will contain the train and test datasets, along with the key.
